# %%
import sys
import numpy as np
import cv2
from keras import backend as K
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix
from keras.layers import Conv2D, Flatten, Dense, MaxPool2D,MaxPooling2D, Activation, Dropout, BatchNormalization, Input
import matplotlib.pyplot as plt
from keras.optimizers import Adam
import itertools

# %%
path = "C:\\DataScience\\ADC\\clothdata1\\"
train_data_path = path+"train"
test_data_path = path+"test"
valid_data_path = path+"valid"

# %%
############################################
# Set image size and batch size

img_rows = 224
img_cols = 224
batch_size = 10

# %%
############################################
# Set Data Generator for training, testing and validataion.
# Note for testing, set shuffle = false (For proper Confusion matrix)

train_datagen = ImageDataGenerator(featurewise_center=False,  # set input mean to 0 over the dataset
            samplewise_center=False,  # set each sample mean to 0
            featurewise_std_normalization=False,  # divide inputs by std of the dataset
            samplewise_std_normalization=False,  # divide each input by its std
            zca_whitening=False,  # apply ZCA whitening
            rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
            width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
            height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
            horizontal_flip=True,  # randomly flip images
            vertical_flip=False)

train_generator = train_datagen.flow_from_directory(train_data_path,
                                                    target_size=(img_rows, img_cols),
                                                    batch_size=batch_size,
                                                    class_mode='categorical', shuffle=True)

valid_datagen = ImageDataGenerator()
valid_generator = valid_datagen.flow_from_directory(valid_data_path,
                                                    target_size=(img_rows, img_cols),
                                                    batch_size=batch_size,
                                                    class_mode='categorical', shuffle=True)

test_datagen = ImageDataGenerator()
test_generator = test_datagen.flow_from_directory(test_data_path,
                                                    target_size=(img_rows, img_cols),
                                                    batch_size=batch_size,
                                                    class_mode='categorical', shuffle=False)
# Out:
# Found 643 images belonging to 12 classes.
# Found 273 images belonging to 12 classes.
# Found 273 images belonging to 12 classes.

# %%
#########################################################################
# Function for plots images with labels within jupyter notebook


def plots(ims, figsize=(12,12), rows=1, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != 3):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1


    for i in range(len(ims)):
        sp = f.add_subplot(cols, rows, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(titles[i], fontsize=12)
        plt.imshow(ims[i], interpolation=None if interp else 'none')

# %%
#########################################################################
#Check the training set (with batch of 10 as defined above

imgs, labels = next(train_generator)
num_classes = 12
#Images are shown in the output
plots(imgs, titles=labels)

#Images Classes with index
print(train_generator.class_indices)


#Model Creation / Sequential
model = Sequential([Conv2D(16, (3, 3), padding ='same',activation='relu', 
                           input_shape=(img_rows, img_cols, 3)),
                    MaxPooling2D(),
                    Conv2D(32, (3, 3), padding ='same',activation='relu',
                           input_shape=(img_rows, img_cols, 3)),
                    MaxPooling2D(),    
                    Conv2D(64, (3, 3), padding ='same',activation='relu', 
                           input_shape=(img_rows, img_cols, 3)),
                    MaxPooling2D(),  
                    Conv2D(128, (3, 3), padding ='same',activation='relu', 
                           input_shape=(img_rows, img_cols, 3)),
                    MaxPooling2D(),  
                    Flatten(), 
                    Dense(12, activation='softmax')
                   ])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\matplotlib\text.py:1163: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# {'Addidas': 0, "Birki's": 1, 'Brother': 2, 'Hilleberg': 3, 'Husky': 4, 'K-Swiss': 5, 'Pillsbury': 6, 'Salewa': 7, 'Springfield': 8, 'Unicef': 9, 'Vans': 10, 'White Castle': 11}

# %%
#Get summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 12)                301068
# =================================================================
# Total params: 398,508
# Trainable params: 398,508
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
#Train the model
history = model.fit_generator(train_generator, steps_per_epoch=20, validation_data=valid_generator, 
                              validation_steps=4, epochs=100)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\keras\engine\training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 20/20 [==============================] - 18s 309ms/step - loss: 51.1193 - accuracy: 0.0905 - val_loss: 2.3921 - val_accuracy: 0.2500
# Epoch 2/100
# 20/20 [==============================] - 6s 274ms/step - loss: 2.2516 - accuracy: 0.2872 - val_loss: 2.2693 - val_accuracy: 0.2500
# Epoch 3/100
# 20/20 [==============================] - 5s 265ms/step - loss: 1.8723 - accuracy: 0.3793 - val_loss: 1.8904 - val_accuracy: 0.3250
# Epoch 4/100
# 20/20 [==============================] - 5s 263ms/step - loss: 1.8173 - accuracy: 0.4220 - val_loss: 1.5302 - val_accuracy: 0.5250
# Epoch 5/100
# 20/20 [==============================] - 6s 273ms/step - loss: 1.7313 - accuracy: 0.4292 - val_loss: 1.2808 - val_accuracy: 0.6750
# Epoch 6/100
# 20/20 [==============================] - 6s 279ms/step - loss: 1.3369 - accuracy: 0.5448 - val_loss: 1.4689 - val_accuracy: 0.5500
# Epoch 7/100
# 20/20 [==============================] - 6s 290ms/step - loss: 1.1337 - accuracy: 0.6589 - val_loss: 1.3223 - val_accuracy: 0.6750
# Epoch 8/100
# 20/20 [==============================] - 6s 281ms/step - loss: 0.9824 - accuracy: 0.6803 - val_loss: 1.6749 - val_accuracy: 0.5750
# Epoch 9/100
# 20/20 [==============================] - 6s 294ms/step - loss: 0.9449 - accuracy: 0.6887 - val_loss: 1.7733 - val_accuracy: 0.5500
# Epoch 10/100
# 20/20 [==============================] - 6s 286ms/step - loss: 0.7712 - accuracy: 0.7450 - val_loss: 1.4658 - val_accuracy: 0.6500
# Epoch 11/100
# 20/20 [==============================] - 6s 293ms/step - loss: 1.0624 - accuracy: 0.7243 - val_loss: 1.2821 - val_accuracy: 0.6500
# Epoch 12/100
# 20/20 [==============================] - 6s 304ms/step - loss: 0.7066 - accuracy: 0.7686 - val_loss: 1.5880 - val_accuracy: 0.6000
# Epoch 13/100
# 20/20 [==============================] - 6s 304ms/step - loss: 0.9699 - accuracy: 0.6791 - val_loss: 1.6585 - val_accuracy: 0.6000
# Epoch 14/100
# 20/20 [==============================] - 6s 307ms/step - loss: 0.8453 - accuracy: 0.7092 - val_loss: 1.3421 - val_accuracy: 0.7000
# Epoch 15/100
# 20/20 [==============================] - 6s 302ms/step - loss: 0.7396 - accuracy: 0.6882 - val_loss: 1.7902 - val_accuracy: 0.5750
# Epoch 16/100
# 20/20 [==============================] - 6s 311ms/step - loss: 1.0230 - accuracy: 0.6757 - val_loss: 1.6737 - val_accuracy: 0.6250
# Epoch 17/100
# 20/20 [==============================] - 6s 304ms/step - loss: 0.8442 - accuracy: 0.6749 - val_loss: 1.3173 - val_accuracy: 0.6750
# Epoch 18/100
# 20/20 [==============================] - 6s 302ms/step - loss: 0.6638 - accuracy: 0.7294 - val_loss: 0.9388 - val_accuracy: 0.8000
# Epoch 19/100
# 20/20 [==============================] - 6s 304ms/step - loss: 0.7900 - accuracy: 0.7370 - val_loss: 1.2480 - val_accuracy: 0.5750
# Epoch 20/100
# 20/20 [==============================] - 6s 309ms/step - loss: 0.7054 - accuracy: 0.7654 - val_loss: 1.5177 - val_accuracy: 0.6250
# Epoch 21/100
# 20/20 [==============================] - 6s 298ms/step - loss: 0.5488 - accuracy: 0.8481 - val_loss: 1.1619 - val_accuracy: 0.6250
# Epoch 22/100
# 20/20 [==============================] - 6s 301ms/step - loss: 0.8302 - accuracy: 0.7095 - val_loss: 1.3460 - val_accuracy: 0.7500
# Epoch 23/100
# 20/20 [==============================] - 6s 296ms/step - loss: 0.7761 - accuracy: 0.7158 - val_loss: 1.0428 - val_accuracy: 0.7750
# Epoch 24/100
# 20/20 [==============================] - 6s 319ms/step - loss: 0.7417 - accuracy: 0.7582 - val_loss: 1.2678 - val_accuracy: 0.6750
# Epoch 25/100
# 20/20 [==============================] - 6s 296ms/step - loss: 0.4925 - accuracy: 0.7762 - val_loss: 1.1249 - val_accuracy: 0.7500
# Epoch 26/100
# 20/20 [==============================] - 6s 303ms/step - loss: 0.4965 - accuracy: 0.8272 - val_loss: 1.2633 - val_accuracy: 0.7750
# Epoch 27/100
# 20/20 [==============================] - 6s 302ms/step - loss: 0.7288 - accuracy: 0.7855 - val_loss: 1.5563 - val_accuracy: 0.7250
# Epoch 28/100
# 20/20 [==============================] - 6s 301ms/step - loss: 0.4130 - accuracy: 0.8814 - val_loss: 2.0193 - val_accuracy: 0.6000
# Epoch 29/100
# 20/20 [==============================] - 6s 294ms/step - loss: 0.5234 - accuracy: 0.8269 - val_loss: 2.0892 - val_accuracy: 0.6500
# Epoch 30/100
# 20/20 [==============================] - 6s 301ms/step - loss: 0.7804 - accuracy: 0.7788 - val_loss: 1.4796 - val_accuracy: 0.6500
# Epoch 31/100
# 20/20 [==============================] - 6s 302ms/step - loss: 0.5675 - accuracy: 0.7955 - val_loss: 1.3460 - val_accuracy: 0.7500
# Epoch 32/100
# 20/20 [==============================] - 6s 302ms/step - loss: 0.3948 - accuracy: 0.8822 - val_loss: 1.6641 - val_accuracy: 0.7000
# Epoch 33/100
# 20/20 [==============================] - 6s 300ms/step - loss: 0.5217 - accuracy: 0.8708 - val_loss: 2.1105 - val_accuracy: 0.6250
# Epoch 34/100
# 20/20 [==============================] - 6s 294ms/step - loss: 0.6449 - accuracy: 0.8395 - val_loss: 2.7604 - val_accuracy: 0.5500
# Epoch 35/100
# 20/20 [==============================] - 6s 305ms/step - loss: 0.6887 - accuracy: 0.7673 - val_loss: 1.0514 - val_accuracy: 0.7000
# Epoch 36/100
# 20/20 [==============================] - 6s 302ms/step - loss: 0.6005 - accuracy: 0.8132 - val_loss: 1.4812 - val_accuracy: 0.6750
# Epoch 37/100
# 20/20 [==============================] - 6s 292ms/step - loss: 0.5294 - accuracy: 0.8211 - val_loss: 1.0688 - val_accuracy: 0.7500
# Epoch 38/100
# 20/20 [==============================] - 6s 294ms/step - loss: 0.6714 - accuracy: 0.7944 - val_loss: 2.2573 - val_accuracy: 0.6750
# Epoch 39/100
# 20/20 [==============================] - 6s 300ms/step - loss: 0.4087 - accuracy: 0.8677 - val_loss: 1.3522 - val_accuracy: 0.6750
# Epoch 40/100
# 20/20 [==============================] - 6s 301ms/step - loss: 0.5223 - accuracy: 0.8188 - val_loss: 2.1206 - val_accuracy: 0.7250
# Epoch 41/100
# 20/20 [==============================] - 6s 302ms/step - loss: 0.7238 - accuracy: 0.7739 - val_loss: 2.3295 - val_accuracy: 0.7500
# Epoch 42/100
# 20/20 [==============================] - 6s 306ms/step - loss: 0.5498 - accuracy: 0.8090 - val_loss: 1.3769 - val_accuracy: 0.7000
# Epoch 43/100
# 20/20 [==============================] - 6s 300ms/step - loss: 0.3798 - accuracy: 0.8949 - val_loss: 2.3440 - val_accuracy: 0.5750
# Epoch 44/100
# 20/20 [==============================] - 7s 330ms/step - loss: 0.4060 - accuracy: 0.8977 - val_loss: 1.5592 - val_accuracy: 0.7750
# Epoch 45/100
# 20/20 [==============================] - 7s 346ms/step - loss: 0.4061 - accuracy: 0.8410 - val_loss: 1.7949 - val_accuracy: 0.7500
# Epoch 46/100
# 20/20 [==============================] - 6s 298ms/step - loss: 0.5593 - accuracy: 0.8094 - val_loss: 0.9909 - val_accuracy: 0.7750
# Epoch 47/100
# 20/20 [==============================] - 7s 341ms/step - loss: 0.3641 - accuracy: 0.8599 - val_loss: 1.8626 - val_accuracy: 0.6000
# Epoch 48/100
# 20/20 [==============================] - 6s 304ms/step - loss: 0.4566 - accuracy: 0.8906 - val_loss: 1.7414 - val_accuracy: 0.6250
# Epoch 49/100
# 20/20 [==============================] - 6s 302ms/step - loss: 0.5103 - accuracy: 0.8151 - val_loss: 1.4699 - val_accuracy: 0.7250
# Epoch 50/100
# 20/20 [==============================] - 6s 300ms/step - loss: 0.4646 - accuracy: 0.8586 - val_loss: 2.2922 - val_accuracy: 0.6500
# Epoch 51/100
# 20/20 [==============================] - 7s 329ms/step - loss: 0.3975 - accuracy: 0.8720 - val_loss: 2.5402 - val_accuracy: 0.7250
# Epoch 52/100
# 20/20 [==============================] - 6s 305ms/step - loss: 0.3247 - accuracy: 0.8854 - val_loss: 2.1151 - val_accuracy: 0.7250
# Epoch 53/100
# 20/20 [==============================] - 6s 303ms/step - loss: 0.3629 - accuracy: 0.8785 - val_loss: 1.2379 - val_accuracy: 0.8500
# Epoch 54/100
# 20/20 [==============================] - 7s 348ms/step - loss: 0.5952 - accuracy: 0.8006 - val_loss: 1.1818 - val_accuracy: 0.7500
# Epoch 55/100
# 20/20 [==============================] - 6s 312ms/step - loss: 0.4615 - accuracy: 0.8404 - val_loss: 1.3820 - val_accuracy: 0.7000
# Epoch 56/100
# 20/20 [==============================] - 6s 311ms/step - loss: 0.2433 - accuracy: 0.9252 - val_loss: 1.8629 - val_accuracy: 0.6750
# Epoch 57/100
# 20/20 [==============================] - 6s 299ms/step - loss: 0.4268 - accuracy: 0.8818 - val_loss: 1.2114 - val_accuracy: 0.8250
# Epoch 58/100
# 20/20 [==============================] - 6s 300ms/step - loss: 0.2390 - accuracy: 0.9444 - val_loss: 1.8787 - val_accuracy: 0.7250
# Epoch 59/100
# 20/20 [==============================] - 6s 292ms/step - loss: 0.4205 - accuracy: 0.8514 - val_loss: 1.2918 - val_accuracy: 0.7500
# Epoch 60/100
# 20/20 [==============================] - 6s 311ms/step - loss: 0.3171 - accuracy: 0.8947 - val_loss: 2.5901 - val_accuracy: 0.6250
# Epoch 61/100
# 20/20 [==============================] - 6s 307ms/step - loss: 0.3120 - accuracy: 0.9244 - val_loss: 1.4850 - val_accuracy: 0.7500
# Epoch 62/100
# 20/20 [==============================] - 6s 295ms/step - loss: 0.3649 - accuracy: 0.8652 - val_loss: 2.0373 - val_accuracy: 0.7000
# Epoch 63/100
# 20/20 [==============================] - 6s 308ms/step - loss: 0.2467 - accuracy: 0.9122 - val_loss: 2.3917 - val_accuracy: 0.7500
# Epoch 64/100
# 20/20 [==============================] - 6s 303ms/step - loss: 0.3681 - accuracy: 0.8996 - val_loss: 2.1544 - val_accuracy: 0.6250
# Epoch 65/100
# 20/20 [==============================] - 6s 294ms/step - loss: 0.3155 - accuracy: 0.8593 - val_loss: 1.8279 - val_accuracy: 0.7250
# Epoch 66/100
# 20/20 [==============================] - 6s 306ms/step - loss: 0.2621 - accuracy: 0.9002 - val_loss: 1.4480 - val_accuracy: 0.7250
# Epoch 67/100
# 20/20 [==============================] - 7s 326ms/step - loss: 0.4315 - accuracy: 0.8552 - val_loss: 2.2410 - val_accuracy: 0.8000
# Epoch 68/100
# 20/20 [==============================] - 8s 374ms/step - loss: 0.3376 - accuracy: 0.8790 - val_loss: 1.8518 - val_accuracy: 0.7500
# Epoch 69/100
# 20/20 [==============================] - 7s 335ms/step - loss: 0.2689 - accuracy: 0.9103 - val_loss: 1.7547 - val_accuracy: 0.6500
# Epoch 70/100
# 20/20 [==============================] - 7s 343ms/step - loss: 0.3559 - accuracy: 0.8966 - val_loss: 2.7031 - val_accuracy: 0.5750
# Epoch 71/100
# 20/20 [==============================] - 7s 336ms/step - loss: 0.4371 - accuracy: 0.8796 - val_loss: 2.1120 - val_accuracy: 0.7000
# Epoch 72/100
# 20/20 [==============================] - 8s 386ms/step - loss: 0.3340 - accuracy: 0.8991 - val_loss: 1.8504 - val_accuracy: 0.7250
# Epoch 73/100
# 20/20 [==============================] - 7s 354ms/step - loss: 0.4764 - accuracy: 0.8753 - val_loss: 2.0975 - val_accuracy: 0.6500
# Epoch 74/100
# 20/20 [==============================] - 7s 347ms/step - loss: 0.2114 - accuracy: 0.9332 - val_loss: 1.7217 - val_accuracy: 0.7000
# Epoch 75/100
# 20/20 [==============================] - 6s 309ms/step - loss: 0.6616 - accuracy: 0.8220 - val_loss: 2.9580 - val_accuracy: 0.6500
# Epoch 76/100
# 20/20 [==============================] - 6s 299ms/step - loss: 0.4800 - accuracy: 0.8351 - val_loss: 1.1170 - val_accuracy: 0.8000
# Epoch 77/100
# 20/20 [==============================] - 7s 329ms/step - loss: 0.4053 - accuracy: 0.8462 - val_loss: 1.9434 - val_accuracy: 0.8000
# Epoch 78/100
# 20/20 [==============================] - 7s 322ms/step - loss: 0.3335 - accuracy: 0.8716 - val_loss: 3.1088 - val_accuracy: 0.5750
# Epoch 79/100
# 20/20 [==============================] - 7s 331ms/step - loss: 0.5460 - accuracy: 0.8233 - val_loss: 2.9432 - val_accuracy: 0.5750
# Epoch 80/100
# 20/20 [==============================] - 6s 294ms/step - loss: 0.3945 - accuracy: 0.8626 - val_loss: 1.0909 - val_accuracy: 0.8250
# Epoch 81/100
# 20/20 [==============================] - 7s 330ms/step - loss: 0.6059 - accuracy: 0.8339 - val_loss: 2.8145 - val_accuracy: 0.6000
# Epoch 82/100
# 20/20 [==============================] - 6s 313ms/step - loss: 0.3429 - accuracy: 0.8879 - val_loss: 2.3965 - val_accuracy: 0.6750
# Epoch 83/100
# 20/20 [==============================] - 7s 329ms/step - loss: 0.3486 - accuracy: 0.8818 - val_loss: 2.1911 - val_accuracy: 0.7250
# Epoch 84/100
# 20/20 [==============================] - 6s 316ms/step - loss: 0.2819 - accuracy: 0.9006 - val_loss: 1.3271 - val_accuracy: 0.8000
# Epoch 85/100
# 20/20 [==============================] - 7s 326ms/step - loss: 0.2591 - accuracy: 0.8875 - val_loss: 1.3034 - val_accuracy: 0.7750
# Epoch 86/100
# 20/20 [==============================] - 8s 373ms/step - loss: 0.3361 - accuracy: 0.8879 - val_loss: 0.4129 - val_accuracy: 0.8750
# Epoch 87/100
# 20/20 [==============================] - 7s 349ms/step - loss: 0.3701 - accuracy: 0.8595 - val_loss: 1.8675 - val_accuracy: 0.7000
# Epoch 88/100
# 20/20 [==============================] - 7s 359ms/step - loss: 0.3409 - accuracy: 0.8608 - val_loss: 1.8029 - val_accuracy: 0.7500
# Epoch 89/100
# 20/20 [==============================] - 7s 329ms/step - loss: 0.2138 - accuracy: 0.9159 - val_loss: 1.6672 - val_accuracy: 0.8250
# Epoch 90/100
# 20/20 [==============================] - 6s 298ms/step - loss: 0.2314 - accuracy: 0.9349 - val_loss: 2.4887 - val_accuracy: 0.7250
# Epoch 91/100
# 20/20 [==============================] - 7s 345ms/step - loss: 0.2615 - accuracy: 0.9039 - val_loss: 1.5476 - val_accuracy: 0.8250
# Epoch 92/100
# 20/20 [==============================] - 6s 303ms/step - loss: 0.3138 - accuracy: 0.8760 - val_loss: 1.7501 - val_accuracy: 0.7250
# Epoch 93/100
# 20/20 [==============================] - 7s 324ms/step - loss: 0.2331 - accuracy: 0.9160 - val_loss: 2.4477 - val_accuracy: 0.7750
# Epoch 94/100
# 20/20 [==============================] - 7s 325ms/step - loss: 0.2610 - accuracy: 0.9126 - val_loss: 3.4988 - val_accuracy: 0.5500
# Epoch 95/100
# 20/20 [==============================] - 6s 304ms/step - loss: 0.4644 - accuracy: 0.8565 - val_loss: 1.6101 - val_accuracy: 0.6750
# Epoch 96/100
# 20/20 [==============================] - 7s 336ms/step - loss: 0.3306 - accuracy: 0.9136 - val_loss: 1.2519 - val_accuracy: 0.7500
# Epoch 97/100
# 20/20 [==============================] - 7s 330ms/step - loss: 0.4974 - accuracy: 0.8460 - val_loss: 2.1258 - val_accuracy: 0.7000
# Epoch 98/100
# 20/20 [==============================] - 7s 348ms/step - loss: 0.1804 - accuracy: 0.9295 - val_loss: 2.2156 - val_accuracy: 0.6500
# Epoch 99/100
# 20/20 [==============================] - 7s 345ms/step - loss: 0.2227 - accuracy: 0.9360 - val_loss: 2.2466 - val_accuracy: 0.6750
# Epoch 100/100
# 20/20 [==============================] - 7s 347ms/step - loss: 0.2653 - accuracy: 0.8808 - val_loss: 0.7383 - val_accuracy: 0.8750

# %%
#Get the accuracy score

test_score = model.evaluate_generator(test_generator, batch_size)
print("[INFO] accuracy: {:.2f}%".format(test_score[1] * 100)) 
print("[INFO] Loss: ",test_score[0])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\keras\engine\training.py:1948: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# [INFO] accuracy: 80.00%
# [INFO] Loss:  2.039560556411743

# %%
#Plot the Graph

# Loss Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['loss'],'r',linewidth=3.0)
plt.plot(history.history['val_loss'],'b',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)



# Accuracy Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['accuracy'],'r',linewidth=3.0)
plt.plot(history.history['val_accuracy'],'b',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Accuracy Curves',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Accuracy Curves')

# %%
##################################################################################################
#Plot the confusion matrix. Set Normalize = True/False


def plot_confusion_matrix(cm, classes, normalize=True, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=2)
        cm[np.isnan(cm)] = 0.0
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
#Print the Target names

target_names = []
for key in train_generator.class_indices:
    target_names.append(key)

print(target_names)
# Out:
# ['Addidas', "Birki's", 'Brother', 'Hilleberg', 'Husky', 'K-Swiss', 'Pillsbury', 'Salewa', 'Springfield', 'Unicef', 'Vans', 'White Castle']

# %%
#Confution Matrix 

Y_pred = model.predict_generator(test_generator)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
cm = confusion_matrix(test_generator.classes, y_pred)
plot_confusion_matrix(cm, target_names, title='Confusion Matrix')
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\keras\engine\training.py:1976: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# Confusion Matrix
# Normalized confusion matrix

# %%
#Print Classification Report

print('Classification Report')
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#      Addidas       0.75      0.60      0.67        35
#      Birki's       1.00      0.90      0.95        21
#      Brother       0.79      0.90      0.84        21
#    Hilleberg       1.00      0.90      0.95        20
#        Husky       0.52      0.74      0.61        31
#      K-Swiss       0.67      0.31      0.42        13
#    Pillsbury       0.86      0.82      0.84        22
#       Salewa       0.96      0.90      0.93        30
#  Springfield       0.22      0.31      0.26        13
#       Unicef       0.42      0.58      0.49        19
#         Vans       0.80      0.57      0.67        21
# White Castle       0.88      0.85      0.87        27
#
#     accuracy                           0.73       273
#    macro avg       0.74      0.70      0.71       273
# weighted avg       0.76      0.73      0.74       273

# %%
#Save the model
model.save("goodbase_confusion.hdf5")

# %%
#Test the model

from keras.models import load_model
img_rows = 224
img_cols = 224

model = load_model("goodbase_confusion.hdf5")
