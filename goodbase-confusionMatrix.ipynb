# %%
import sys
import numpy as np
import cv2
from keras import backend as K
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix
from keras.layers import Conv2D, Flatten, Dense, MaxPool2D,MaxPooling2D, Activation, Dropout, BatchNormalization, Input
import matplotlib.pyplot as plt
from keras.optimizers import Adam
import itertools

# %%
path = "C:\\DataScience\\ADC\\clothdata1\\"
train_data_path = path+"train"
test_data_path = path+"test"
valid_data_path = path+"valid"

# %%
############################################
# Set image size and batch size

img_rows = 224
img_cols = 224
batch_size = 10

# %%
############################################
# Set Data Generator for training, testing and validataion.
# Note for testing, set shuffle = false (For proper Confusion matrix)

train_datagen = ImageDataGenerator(zoom_range=0.2, 
                                   width_shift_range=0.2,
                                   horizontal_flip=True,
                                   rotation_range=10,
                                   fill_mode="constant",
                                   cval=0)
train_generator = train_datagen.flow_from_directory(train_data_path,
                                                    target_size=(img_rows, img_cols),
                                                    batch_size=batch_size,
                                                    class_mode='categorical', shuffle=True)

valid_datagen = ImageDataGenerator()
valid_generator = valid_datagen.flow_from_directory(valid_data_path,
                                                    target_size=(img_rows, img_cols),
                                                    batch_size=batch_size,
                                                    class_mode='categorical', shuffle=True)

test_datagen = ImageDataGenerator()
test_generator = test_datagen.flow_from_directory(test_data_path,
                                                    target_size=(img_rows, img_cols),
                                                    batch_size=batch_size,
                                                    class_mode='categorical', shuffle=False)
# Out:
# Found 643 images belonging to 12 classes.
# Found 273 images belonging to 12 classes.
# Found 273 images belonging to 12 classes.

# %%
#########################################################################
# Function for plots images with labels within jupyter notebook


def plots(ims, figsize=(12,12), rows=1, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != 3):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1


    for i in range(len(ims)):
        sp = f.add_subplot(cols, rows, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(titles[i], fontsize=12)
        plt.imshow(ims[i], interpolation=None if interp else 'none')

# %%
#########################################################################
#Check the training set (with batch of 10 as defined above

imgs, labels = next(train_generator)
num_classes = 12
#Images are shown in the output
plots(imgs, titles=labels)

#Images Classes with index
print(train_generator.class_indices)


#Model Creation / Sequential
model = Sequential([Conv2D(16, (3, 3), padding ='same',activation='relu', 
                           input_shape=(img_rows, img_cols, 3)),
                    MaxPooling2D(),
                    Conv2D(32, (3, 3), padding ='same',activation='relu',
                           input_shape=(img_rows, img_cols, 3)),
                    MaxPooling2D(),    
                    Conv2D(64, (3, 3), padding ='same',activation='relu', 
                           input_shape=(img_rows, img_cols, 3)),
                    MaxPooling2D(),  
                    Conv2D(128, (3, 3), padding ='same',activation='relu', 
                           input_shape=(img_rows, img_cols, 3)),
                    MaxPooling2D(),  
                    Flatten(), 
                    Dense(12, activation='softmax')
                   ])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\matplotlib\text.py:1163: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# {'Addidas': 0, "Birki's": 1, 'Brother': 2, 'Hilleberg': 3, 'Husky': 4, 'K-Swiss': 5, 'Pillsbury': 6, 'Salewa': 7, 'Springfield': 8, 'Unicef': 9, 'Vans': 10, 'White Castle': 11}

# %%
#Get summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 12)                301068
# =================================================================
# Total params: 398,508
# Trainable params: 398,508
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
#Train the model
history = model.fit_generator(train_generator, steps_per_epoch=20, validation_data=valid_generator, 
                              validation_steps=4, epochs=100)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\keras\engine\training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 20/20 [==============================] - 17s 285ms/step - loss: 67.2097 - accuracy: 0.1041 - val_loss: 2.1641 - val_accuracy: 0.3000
# Epoch 2/100
# 20/20 [==============================] - 5s 261ms/step - loss: 2.3225 - accuracy: 0.2148 - val_loss: 2.1236 - val_accuracy: 0.3000
# Epoch 3/100
# 20/20 [==============================] - 6s 277ms/step - loss: 2.2026 - accuracy: 0.2635 - val_loss: 1.6442 - val_accuracy: 0.5250
# Epoch 4/100
# 20/20 [==============================] - 6s 290ms/step - loss: 1.7409 - accuracy: 0.4374 - val_loss: 2.2440 - val_accuracy: 0.3000
# Epoch 5/100
# 20/20 [==============================] - 5s 265ms/step - loss: 1.9078 - accuracy: 0.3422 - val_loss: 1.9862 - val_accuracy: 0.5000
# Epoch 6/100
# 20/20 [==============================] - 5s 254ms/step - loss: 1.7070 - accuracy: 0.4474 - val_loss: 1.7167 - val_accuracy: 0.4500
# Epoch 7/100
# 20/20 [==============================] - 6s 273ms/step - loss: 1.9423 - accuracy: 0.3759 - val_loss: 1.9941 - val_accuracy: 0.4500
# Epoch 8/100
# 20/20 [==============================] - 6s 294ms/step - loss: 1.7805 - accuracy: 0.4222 - val_loss: 1.2667 - val_accuracy: 0.5750
# Epoch 9/100
# 20/20 [==============================] - 6s 317ms/step - loss: 1.7471 - accuracy: 0.4381 - val_loss: 1.9805 - val_accuracy: 0.3000
# Epoch 10/100
# 20/20 [==============================] - 6s 296ms/step - loss: 1.6030 - accuracy: 0.4500 - val_loss: 1.8377 - val_accuracy: 0.5250
# Epoch 11/100
# 20/20 [==============================] - 6s 302ms/step - loss: 1.4952 - accuracy: 0.4423 - val_loss: 1.2921 - val_accuracy: 0.5750
# Epoch 12/100
# 20/20 [==============================] - 7s 342ms/step - loss: 1.5566 - accuracy: 0.4529 - val_loss: 1.6039 - val_accuracy: 0.4750
# Epoch 13/100
# 20/20 [==============================] - 8s 378ms/step - loss: 1.5480 - accuracy: 0.5260 - val_loss: 1.6567 - val_accuracy: 0.4750
# Epoch 14/100
# 20/20 [==============================] - 7s 356ms/step - loss: 1.4964 - accuracy: 0.4551 - val_loss: 1.3108 - val_accuracy: 0.5500
# Epoch 15/100
# 20/20 [==============================] - 7s 340ms/step - loss: 1.3036 - accuracy: 0.5645 - val_loss: 1.3408 - val_accuracy: 0.6000
# Epoch 16/100
# 20/20 [==============================] - 7s 315ms/step - loss: 1.2873 - accuracy: 0.5868 - val_loss: 1.5254 - val_accuracy: 0.4250
# Epoch 17/100
# 20/20 [==============================] - 6s 299ms/step - loss: 1.1805 - accuracy: 0.6310 - val_loss: 1.2811 - val_accuracy: 0.5500
# Epoch 18/100
# 20/20 [==============================] - 6s 321ms/step - loss: 1.1926 - accuracy: 0.6112 - val_loss: 1.2616 - val_accuracy: 0.6750
# Epoch 19/100
# 20/20 [==============================] - 7s 327ms/step - loss: 1.2236 - accuracy: 0.6219 - val_loss: 1.6106 - val_accuracy: 0.7000
# Epoch 20/100
# 20/20 [==============================] - 6s 305ms/step - loss: 1.0762 - accuracy: 0.6380 - val_loss: 1.1856 - val_accuracy: 0.6250
# Epoch 21/100
# 20/20 [==============================] - 7s 343ms/step - loss: 1.2630 - accuracy: 0.5850 - val_loss: 1.7918 - val_accuracy: 0.6500
# Epoch 22/100
# 20/20 [==============================] - 7s 344ms/step - loss: 1.1446 - accuracy: 0.6070 - val_loss: 1.0649 - val_accuracy: 0.6750
# Epoch 23/100
# 20/20 [==============================] - 7s 329ms/step - loss: 1.0917 - accuracy: 0.5989 - val_loss: 1.2953 - val_accuracy: 0.6250
# Epoch 24/100
# 20/20 [==============================] - 6s 310ms/step - loss: 1.0864 - accuracy: 0.6430 - val_loss: 1.2788 - val_accuracy: 0.5750
# Epoch 25/100
# 20/20 [==============================] - 7s 330ms/step - loss: 1.1291 - accuracy: 0.6134 - val_loss: 1.2200 - val_accuracy: 0.7000
# Epoch 26/100
# 20/20 [==============================] - 6s 288ms/step - loss: 0.8910 - accuracy: 0.7072 - val_loss: 1.5953 - val_accuracy: 0.6750
# Epoch 27/100
# 20/20 [==============================] - 6s 296ms/step - loss: 1.0166 - accuracy: 0.6355 - val_loss: 1.1230 - val_accuracy: 0.6500
# Epoch 28/100
# 20/20 [==============================] - 6s 288ms/step - loss: 1.1340 - accuracy: 0.6100 - val_loss: 1.4747 - val_accuracy: 0.5750
# Epoch 29/100
# 20/20 [==============================] - 6s 301ms/step - loss: 1.1702 - accuracy: 0.5994 - val_loss: 1.6859 - val_accuracy: 0.6000
# Epoch 30/100
# 20/20 [==============================] - 6s 292ms/step - loss: 1.1217 - accuracy: 0.6114 - val_loss: 1.9799 - val_accuracy: 0.5000
# Epoch 31/100
# 20/20 [==============================] - 6s 305ms/step - loss: 1.2552 - accuracy: 0.5793 - val_loss: 0.7654 - val_accuracy: 0.8250
# Epoch 32/100
# 20/20 [==============================] - 7s 348ms/step - loss: 0.9404 - accuracy: 0.6706 - val_loss: 2.1030 - val_accuracy: 0.5250
# Epoch 33/100
# 20/20 [==============================] - 7s 348ms/step - loss: 1.0731 - accuracy: 0.7016 - val_loss: 1.3827 - val_accuracy: 0.6500
# Epoch 34/100
# 20/20 [==============================] - 6s 300ms/step - loss: 0.9823 - accuracy: 0.6934 - val_loss: 1.1033 - val_accuracy: 0.7250
# Epoch 35/100
# 20/20 [==============================] - 7s 358ms/step - loss: 1.0128 - accuracy: 0.6781 - val_loss: 0.9789 - val_accuracy: 0.6750
# Epoch 36/100
# 20/20 [==============================] - 6s 306ms/step - loss: 0.8899 - accuracy: 0.6610 - val_loss: 0.7770 - val_accuracy: 0.8000
# Epoch 37/100
# 20/20 [==============================] - 6s 319ms/step - loss: 0.8495 - accuracy: 0.7461 - val_loss: 0.9626 - val_accuracy: 0.7250
# Epoch 38/100
# 20/20 [==============================] - 6s 305ms/step - loss: 0.9213 - accuracy: 0.6634 - val_loss: 1.2708 - val_accuracy: 0.6750
# Epoch 39/100
# 20/20 [==============================] - 6s 296ms/step - loss: 1.0378 - accuracy: 0.6642 - val_loss: 1.4217 - val_accuracy: 0.5750
# Epoch 40/100
# 20/20 [==============================] - 6s 303ms/step - loss: 0.8794 - accuracy: 0.7032 - val_loss: 1.3511 - val_accuracy: 0.5750
# Epoch 41/100
# 20/20 [==============================] - 6s 305ms/step - loss: 0.8334 - accuracy: 0.7358 - val_loss: 1.7048 - val_accuracy: 0.5250
# Epoch 42/100
# 20/20 [==============================] - 6s 314ms/step - loss: 0.6996 - accuracy: 0.7846 - val_loss: 1.2241 - val_accuracy: 0.6500
# Epoch 43/100
# 20/20 [==============================] - 7s 340ms/step - loss: 0.8382 - accuracy: 0.7138 - val_loss: 1.1730 - val_accuracy: 0.6000
# Epoch 44/100
# 20/20 [==============================] - 6s 299ms/step - loss: 0.8621 - accuracy: 0.6671 - val_loss: 1.6824 - val_accuracy: 0.6000
# Epoch 45/100
# 20/20 [==============================] - 6s 298ms/step - loss: 0.8014 - accuracy: 0.7185 - val_loss: 1.2198 - val_accuracy: 0.6250
# Epoch 46/100
# 20/20 [==============================] - 6s 312ms/step - loss: 0.8171 - accuracy: 0.7378 - val_loss: 1.2354 - val_accuracy: 0.6750
# Epoch 47/100
# 20/20 [==============================] - 6s 302ms/step - loss: 0.7208 - accuracy: 0.7366 - val_loss: 1.0945 - val_accuracy: 0.7000
# Epoch 48/100
# 20/20 [==============================] - 6s 295ms/step - loss: 0.8192 - accuracy: 0.6925 - val_loss: 1.0772 - val_accuracy: 0.6500
# Epoch 49/100
# 20/20 [==============================] - 6s 309ms/step - loss: 0.8557 - accuracy: 0.7064 - val_loss: 1.3003 - val_accuracy: 0.7000
# Epoch 50/100
# 20/20 [==============================] - 7s 333ms/step - loss: 0.8528 - accuracy: 0.7210 - val_loss: 1.3647 - val_accuracy: 0.6000
# Epoch 51/100
# 20/20 [==============================] - 7s 357ms/step - loss: 0.6192 - accuracy: 0.7843 - val_loss: 1.3845 - val_accuracy: 0.6750
# Epoch 52/100
# 20/20 [==============================] - 8s 387ms/step - loss: 0.8835 - accuracy: 0.7108 - val_loss: 1.4936 - val_accuracy: 0.6750
# Epoch 53/100
# 20/20 [==============================] - 7s 362ms/step - loss: 0.5487 - accuracy: 0.8347 - val_loss: 1.5978 - val_accuracy: 0.5750
# Epoch 54/100
# 20/20 [==============================] - 6s 313ms/step - loss: 0.7881 - accuracy: 0.7177 - val_loss: 1.4552 - val_accuracy: 0.6000
# Epoch 55/100
# 20/20 [==============================] - 6s 311ms/step - loss: 0.5944 - accuracy: 0.8395 - val_loss: 1.6802 - val_accuracy: 0.7000
# Epoch 56/100
# 20/20 [==============================] - 6s 310ms/step - loss: 0.7937 - accuracy: 0.7558 - val_loss: 1.3873 - val_accuracy: 0.6500
# Epoch 57/100
# 20/20 [==============================] - 7s 319ms/step - loss: 0.7668 - accuracy: 0.7896 - val_loss: 1.8529 - val_accuracy: 0.5750
# Epoch 58/100
# 20/20 [==============================] - 6s 313ms/step - loss: 0.7792 - accuracy: 0.7400 - val_loss: 1.9603 - val_accuracy: 0.5500
# Epoch 59/100
# 20/20 [==============================] - 6s 316ms/step - loss: 0.6813 - accuracy: 0.7394 - val_loss: 1.3333 - val_accuracy: 0.6500
# Epoch 60/100
# 20/20 [==============================] - 6s 306ms/step - loss: 0.5773 - accuracy: 0.8159 - val_loss: 1.5314 - val_accuracy: 0.5250
# Epoch 61/100
# 20/20 [==============================] - 6s 308ms/step - loss: 0.7664 - accuracy: 0.7729 - val_loss: 1.2828 - val_accuracy: 0.7000
# Epoch 62/100
# 20/20 [==============================] - 6s 298ms/step - loss: 0.7495 - accuracy: 0.7793 - val_loss: 1.4260 - val_accuracy: 0.7000
# Epoch 63/100
# 20/20 [==============================] - 6s 294ms/step - loss: 0.8259 - accuracy: 0.7156 - val_loss: 1.3478 - val_accuracy: 0.6250
# Epoch 64/100
# 20/20 [==============================] - 6s 315ms/step - loss: 0.6640 - accuracy: 0.7941 - val_loss: 2.1427 - val_accuracy: 0.5750
# Epoch 65/100
# 20/20 [==============================] - 6s 310ms/step - loss: 0.7259 - accuracy: 0.7594 - val_loss: 1.8055 - val_accuracy: 0.5250
# Epoch 66/100
# 20/20 [==============================] - 6s 316ms/step - loss: 0.5322 - accuracy: 0.8377 - val_loss: 1.5444 - val_accuracy: 0.6750
# Epoch 67/100
# 20/20 [==============================] - 6s 312ms/step - loss: 0.5399 - accuracy: 0.8102 - val_loss: 1.3727 - val_accuracy: 0.6250
# Epoch 68/100
# 20/20 [==============================] - 6s 308ms/step - loss: 0.5721 - accuracy: 0.8225 - val_loss: 1.5703 - val_accuracy: 0.6000
# Epoch 69/100
# 20/20 [==============================] - 6s 315ms/step - loss: 0.6893 - accuracy: 0.7562 - val_loss: 1.6693 - val_accuracy: 0.6500
# Epoch 70/100
# 20/20 [==============================] - 7s 360ms/step - loss: 0.4850 - accuracy: 0.8391 - val_loss: 1.3379 - val_accuracy: 0.7000
# Epoch 71/100
# 20/20 [==============================] - 7s 339ms/step - loss: 0.8041 - accuracy: 0.7469 - val_loss: 2.0325 - val_accuracy: 0.7000
# Epoch 72/100
# 20/20 [==============================] - 7s 354ms/step - loss: 0.9284 - accuracy: 0.7020 - val_loss: 1.4766 - val_accuracy: 0.6250
# Epoch 73/100
# 20/20 [==============================] - 6s 313ms/step - loss: 0.7596 - accuracy: 0.7251 - val_loss: 1.1145 - val_accuracy: 0.7000
# Epoch 74/100
# 20/20 [==============================] - 7s 361ms/step - loss: 0.5868 - accuracy: 0.7969 - val_loss: 1.7452 - val_accuracy: 0.5750
# Epoch 75/100
# 20/20 [==============================] - 7s 355ms/step - loss: 0.5242 - accuracy: 0.7891 - val_loss: 1.9123 - val_accuracy: 0.6500
# Epoch 76/100
# 20/20 [==============================] - 6s 319ms/step - loss: 0.7006 - accuracy: 0.7467 - val_loss: 1.2083 - val_accuracy: 0.7250
# Epoch 77/100
# 20/20 [==============================] - 7s 345ms/step - loss: 0.4972 - accuracy: 0.8044 - val_loss: 1.4381 - val_accuracy: 0.6750
# Epoch 78/100
# 20/20 [==============================] - 6s 311ms/step - loss: 0.5252 - accuracy: 0.7946 - val_loss: 2.6640 - val_accuracy: 0.5750
# Epoch 79/100
# 20/20 [==============================] - 6s 307ms/step - loss: 0.5152 - accuracy: 0.8092 - val_loss: 1.1979 - val_accuracy: 0.7000
# Epoch 80/100
# 20/20 [==============================] - 6s 312ms/step - loss: 0.6579 - accuracy: 0.7772 - val_loss: 1.6316 - val_accuracy: 0.6500
# Epoch 81/100
# 20/20 [==============================] - 6s 299ms/step - loss: 0.7887 - accuracy: 0.7577 - val_loss: 2.1677 - val_accuracy: 0.6500
# Epoch 82/100
# 20/20 [==============================] - 6s 298ms/step - loss: 0.8303 - accuracy: 0.7845 - val_loss: 1.8734 - val_accuracy: 0.6000
# Epoch 83/100
# 20/20 [==============================] - 6s 305ms/step - loss: 0.5402 - accuracy: 0.8019 - val_loss: 2.0551 - val_accuracy: 0.6000
# Epoch 84/100
# 20/20 [==============================] - 6s 292ms/step - loss: 0.7717 - accuracy: 0.7933 - val_loss: 1.2175 - val_accuracy: 0.6000
# Epoch 85/100
# 20/20 [==============================] - 6s 295ms/step - loss: 0.7956 - accuracy: 0.7822 - val_loss: 1.2356 - val_accuracy: 0.6250
# Epoch 86/100
# 20/20 [==============================] - 6s 301ms/step - loss: 0.6810 - accuracy: 0.7800 - val_loss: 1.1429 - val_accuracy: 0.7750
# Epoch 87/100
# 20/20 [==============================] - 6s 305ms/step - loss: 0.7858 - accuracy: 0.7323 - val_loss: 1.0027 - val_accuracy: 0.7250
# Epoch 88/100
# 20/20 [==============================] - 6s 313ms/step - loss: 0.7190 - accuracy: 0.7609 - val_loss: 1.9575 - val_accuracy: 0.5750
# Epoch 89/100
# 20/20 [==============================] - 6s 320ms/step - loss: 0.6043 - accuracy: 0.7850 - val_loss: 1.4348 - val_accuracy: 0.7500
# Epoch 90/100
# 20/20 [==============================] - 6s 301ms/step - loss: 0.5835 - accuracy: 0.8224 - val_loss: 2.2398 - val_accuracy: 0.6250
# Epoch 91/100
# 20/20 [==============================] - 6s 301ms/step - loss: 0.4903 - accuracy: 0.8469 - val_loss: 2.3351 - val_accuracy: 0.6500
# Epoch 92/100
# 20/20 [==============================] - 7s 339ms/step - loss: 0.5852 - accuracy: 0.8076 - val_loss: 1.4614 - val_accuracy: 0.6500
# Epoch 93/100
# 20/20 [==============================] - 6s 308ms/step - loss: 0.2969 - accuracy: 0.8738 - val_loss: 2.0062 - val_accuracy: 0.5750
# Epoch 94/100
# 20/20 [==============================] - 6s 312ms/step - loss: 0.2802 - accuracy: 0.9229 - val_loss: 2.3331 - val_accuracy: 0.6500
# Epoch 95/100
# 20/20 [==============================] - 7s 323ms/step - loss: 0.4723 - accuracy: 0.8435 - val_loss: 1.4263 - val_accuracy: 0.6250
# Epoch 96/100
# 20/20 [==============================] - 8s 413ms/step - loss: 0.5061 - accuracy: 0.8552 - val_loss: 1.3285 - val_accuracy: 0.7500
# Epoch 97/100
# 20/20 [==============================] - 8s 355ms/step - loss: 0.5210 - accuracy: 0.8040 - val_loss: 1.8609 - val_accuracy: 0.6500
# Epoch 98/100
# 20/20 [==============================] - 7s 348ms/step - loss: 0.4503 - accuracy: 0.8657 - val_loss: 1.5484 - val_accuracy: 0.5500
# Epoch 99/100
# 20/20 [==============================] - 8s 401ms/step - loss: 0.6712 - accuracy: 0.7996 - val_loss: 1.3367 - val_accuracy: 0.6750
# Epoch 100/100
# 20/20 [==============================] - 8s 360ms/step - loss: 0.3470 - accuracy: 0.8832 - val_loss: 1.6851 - val_accuracy: 0.7750

# %%
#Get the accuracy score

test_score = model.evaluate_generator(test_generator, batch_size)
print("[INFO] accuracy: {:.2f}%".format(test_score[1] * 100)) 
print("[INFO] Loss: ",test_score[0])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\keras\engine\training.py:1948: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# [INFO] accuracy: 81.00%
# [INFO] Loss:  1.6149382591247559

# %%
#Plot the Graph

# Loss Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['loss'],'r',linewidth=3.0)
plt.plot(history.history['val_loss'],'b',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)



# Accuracy Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['accuracy'],'r',linewidth=3.0)
plt.plot(history.history['val_accuracy'],'b',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Accuracy Curves',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Accuracy Curves')

# %%
##################################################################################################
#Plot the confusion matrix. Set Normalize = True/False


def plot_confusion_matrix(cm, classes, normalize=True, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=2)
        cm[np.isnan(cm)] = 0.0
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
#Print the Target names

target_names = []
for key in train_generator.class_indices:
    target_names.append(key)

print(target_names)
# Out:
# ['Addidas', "Birki's", 'Brother', 'Hilleberg', 'Husky', 'K-Swiss', 'Pillsbury', 'Salewa', 'Springfield', 'Unicef', 'Vans', 'White Castle']

# %%
#Confution Matrix 

Y_pred = model.predict_generator(test_generator)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
cm = confusion_matrix(test_generator.classes, y_pred)
plot_confusion_matrix(cm, target_names, title='Confusion Matrix')
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\keras\engine\training.py:1976: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# Confusion Matrix
# Normalized confusion matrix

# %%
#Print Classification Report

print('Classification Report')
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#      Addidas       0.77      0.66      0.71        35
#      Birki's       0.86      0.86      0.86        21
#      Brother       0.71      0.95      0.82        21
#    Hilleberg       1.00      0.90      0.95        20
#        Husky       0.54      0.61      0.58        31
#      K-Swiss       0.60      0.46      0.52        13
#    Pillsbury       0.68      0.77      0.72        22
#       Salewa       1.00      0.93      0.97        30
#  Springfield       0.21      0.31      0.25        13
#       Unicef       0.50      0.26      0.34        19
#         Vans       0.71      0.71      0.71        21
# White Castle       0.82      0.85      0.84        27
#
#     accuracy                           0.72       273
#    macro avg       0.70      0.69      0.69       273
# weighted avg       0.73      0.72      0.72       273

# %%
#Save the model
model.save("goodbase_confusion.hdf5")

# %%
#Test the model

from keras.models import load_model
img_rows = 224
img_cols = 224

model = load_model("goodbase_confusion.hdf5")
