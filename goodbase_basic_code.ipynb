# %% [markdown]
# # LOGO CLASSIFICATION

# %%
# Import the basic required utilities and layers
import numpy as np
import os

# Import the required utilities and it layers to load and preprocess the image data
import PIL
import PIL.Image
import tensorflow as tf
import tensorflow_datasets as tfds

# Import the utilities to effective find the paths and list the images
import pathlib

# Import keras uitilities
# from tensorflow import keras
from tensorflow.keras import layers

# %%
#keras

# %%
data_dir = pathlib.Path("C:\\DataScience\\ADC\\clothdata1\\Train")

# %%
print(data_dir)
# Out:
# C:\DataScience\ADC\clothdata1\Train

# %%
# NOT NEEDED
# print(data_dir.parts)

# %%
dirs = [e for e in data_dir.iterdir() if e.is_dir()]
print(dirs)
print (type(dirs))
# Out:
# [WindowsPath('C:/DataScience/ADC/clothdata1/Train/Addidas'), WindowsPath("C:/DataScience/ADC/clothdata1/Train/Birki's"), WindowsPath('C:/DataScience/ADC/clothdata1/Train/Brother'), WindowsPath('C:/DataScience/ADC/clothdata1/Train/Hilleberg'), WindowsPath('C:/DataScience/ADC/clothdata1/Train/Husky'), WindowsPath('C:/DataScience/ADC/clothdata1/Train/K-Swiss'), WindowsPath('C:/DataScience/ADC/clothdata1/Train/Pillsbury'), WindowsPath('C:/DataScience/ADC/clothdata1/Train/Salewa'), WindowsPath('C:/DataScience/ADC/clothdata1/Train/Springfield'), WindowsPath('C:/DataScience/ADC/clothdata1/Train/Unicef'), WindowsPath('C:/DataScience/ADC/clothdata1/Train/Vans'), WindowsPath('C:/DataScience/ADC/clothdata1/Train/White Castle')]
# <class 'list'>

# %%
import os
p=os.listdir(r"C:\DataScience\ADC\clothdata1\Train")
print (type(p))
print (p)
for i in p:
    print(i)
# Out:
# <class 'list'>
# ['Addidas', "Birki's", 'Brother', 'Hilleberg', 'Husky', 'K-Swiss', 'Pillsbury', 'Salewa', 'Springfield', 'Unicef', 'Vans', 'White Castle']
# Addidas
# Birki's
# Brother
# Hilleberg
# Husky
# K-Swiss
# Pillsbury
# Salewa
# Springfield
# Unicef
# Vans
# White Castle

# %% [markdown]
# ### NOTE: Later convert the below into functions

# %%
Addidas = list(data_dir.glob('Addidas/*'))
print (len(Addidas))
PIL.Image.open(str(Addidas[1]))
# Out:
# 57
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x273B6A55070>

# %%
Husky = list(data_dir.glob('Husky/*'))
print (len(Husky))
PIL.Image.open(str(Husky[1]))
# Out:
# 65
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x273C17E1FA0>

# %% [markdown]
# #### ********=======******LOAD IMAGES AS DATASETS********=======******

# %%
# PARAMETERS FOR THE LOADER

batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# ## Step 1:  Split 80% of the images for training, and 20% for testing (validation)

# %%
# Split 80% of the images for training, and 20% for testing (validation)
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 643 files belonging to 12 classes.
# Using 515 files for training.

# %%
print (train_ds)
# Out:
# <BatchDataset shapes: ((None, 180, 180, 3), (None,)), types: (tf.float32, tf.int32)>

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 643 files belonging to 12 classes.
# Using 128 files for validation.

# %% [markdown]
# ##  List the class names in the class_names attribute on these datasets.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Addidas', "Birki's", 'Brother', 'Hilleberg', 'Husky', 'K-Swiss', 'Pillsbury', 'Salewa', 'Springfield', 'Unicef', 'Vans', 'White Castle']

# %% [markdown]
# ### VISUALIZE THE DATA
#
# **The first 9 images from the training dataset**

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Manually iterate over the dataset and retrieve batches of images:

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 180, 180, 3)
# (32,)

# %%
# STANDARDIZE THE DATA
# CURRENT RGB VALUES ARE IN RANGE [0,255]. FOR DEEP LEARNING WE WANT THEM TO BE IN RANGE [0,1]. 
# APPLYING THE RESCALING LAYER FOR FEATURE/IMAGE SCALING
# from tensorflow.keras import layers

normalization_layer = tf.keras.layers.experimental.preprocessing.Rescaling(1./255)

# map the above normalization layer to the dataset 
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]

# %%
# Notice the pixels values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))

# the output shows that mean is nearly zero and standard deviation is one now. 
# So z-score is applied properly for feature scaling
# Out:
# 0.0 1.0

# %%
# Configure the dataset for performance
# .cache() versus .prefetch()
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
print(type(train_ds))
print(type(val_ds))
#print(train_ds.shape)
#print(val_ds.shape)
# Out:
# <class 'tensorflow.python.data.ops.dataset_ops.PrefetchDataset'>
# <class 'tensorflow.python.data.ops.dataset_ops.PrefetchDataset'>

# %%
# APPLY DATA AUGMENTATION to flip the data in angles. 
from tensorflow.keras.models import Sequential
data_augmentation = Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %%
# Check how the data_augmentation images
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# # MODEL TRAINING
# ### Using Data Augmentation
# ### Using Dropout to reduce overfitting (kind of regularization)
# ### Using 0.2 for dropsout 20% of the output units created above.

# %%
# # CREATE THE MODEL
# 3 CONVOLUTION BLOCKS FOR A STANDARD APPROACH TO SEE  HOW THIS ALL BEHAVES
#from tensorflow.keras.models import Sequential
# Have used the 

num_classes = 12

model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
# Compile the model

model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 180, 180, 3)       0
# _________________________________________________________________
# rescaling_1 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 180, 180, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 22, 22, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 30976)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               3965056
# _________________________________________________________________
# dense_1 (Dense)              (None, 12)                1548
# =================================================================
# Total params: 3,990,188
# Trainable params: 3,990,188
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train for few epochs

epochs=20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 17/17 [==============================] - 9s 488ms/step - loss: 2.9920 - accuracy: 0.1172 - val_loss: 2.0163 - val_accuracy: 0.3047
# Epoch 2/20
# 17/17 [==============================] - 7s 423ms/step - loss: 1.9820 - accuracy: 0.3368 - val_loss: 1.6999 - val_accuracy: 0.4219
# Epoch 3/20
# 17/17 [==============================] - 7s 421ms/step - loss: 1.6045 - accuracy: 0.4459 - val_loss: 1.3662 - val_accuracy: 0.5156
# Epoch 4/20
# 17/17 [==============================] - 8s 455ms/step - loss: 1.3336 - accuracy: 0.5633 - val_loss: 1.3972 - val_accuracy: 0.5469
# Epoch 5/20
# 17/17 [==============================] - 8s 497ms/step - loss: 1.2208 - accuracy: 0.5883 - val_loss: 1.2824 - val_accuracy: 0.6016
# Epoch 6/20
# 17/17 [==============================] - 9s 528ms/step - loss: 1.0832 - accuracy: 0.6620 - val_loss: 1.2553 - val_accuracy: 0.6250
# Epoch 7/20
# 17/17 [==============================] - 9s 514ms/step - loss: 0.8484 - accuracy: 0.7298 - val_loss: 1.3970 - val_accuracy: 0.6016
# Epoch 8/20
# 17/17 [==============================] - 8s 486ms/step - loss: 0.8318 - accuracy: 0.7477 - val_loss: 1.2195 - val_accuracy: 0.6484
# Epoch 9/20
# 17/17 [==============================] - 8s 491ms/step - loss: 0.7926 - accuracy: 0.7451 - val_loss: 1.2127 - val_accuracy: 0.6641
# Epoch 10/20
# 17/17 [==============================] - 8s 489ms/step - loss: 0.7112 - accuracy: 0.7702 - val_loss: 1.3988 - val_accuracy: 0.6719
# Epoch 11/20
# 17/17 [==============================] - 8s 492ms/step - loss: 0.6230 - accuracy: 0.7906 - val_loss: 1.2290 - val_accuracy: 0.7031
# Epoch 12/20
# 17/17 [==============================] - 8s 492ms/step - loss: 0.5486 - accuracy: 0.8178 - val_loss: 1.2485 - val_accuracy: 0.7031
# Epoch 13/20
# 17/17 [==============================] - 8s 492ms/step - loss: 0.5259 - accuracy: 0.8155 - val_loss: 1.1391 - val_accuracy: 0.7188
# Epoch 14/20
# 17/17 [==============================] - 9s 529ms/step - loss: 0.4794 - accuracy: 0.8256 - val_loss: 1.2669 - val_accuracy: 0.7031
# Epoch 15/20
# 17/17 [==============================] - 9s 499ms/step - loss: 0.4075 - accuracy: 0.8353 - val_loss: 1.2610 - val_accuracy: 0.7344
# Epoch 16/20
# 17/17 [==============================] - 8s 497ms/step - loss: 0.3747 - accuracy: 0.8854 - val_loss: 1.0951 - val_accuracy: 0.7422
# Epoch 17/20
# 17/17 [==============================] - 8s 493ms/step - loss: 0.3340 - accuracy: 0.8962 - val_loss: 1.3504 - val_accuracy: 0.6719
# Epoch 18/20
# 17/17 [==============================] - 8s 492ms/step - loss: 0.4476 - accuracy: 0.8639 - val_loss: 1.1729 - val_accuracy: 0.6953
# Epoch 19/20
# 17/17 [==============================] - 9s 504ms/step - loss: 0.4702 - accuracy: 0.8261 - val_loss: 1.0364 - val_accuracy: 0.7734
# Epoch 20/20
# 17/17 [==============================] - 8s 494ms/step - loss: 0.3809 - accuracy: 0.8882 - val_loss: 1.4287 - val_accuracy: 0.6953

# %%
# VISUALIZE TRAINING RESULTS

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# TEST THE MODEL
#from keras.preprocessing import image
# Test path for each image C:\Users\Admin\Desktop\ClothTestFolder

validate_image_dir = pathlib.Path("C:\\Users\\Admin\\Desktop\\ClothTestFolder\\")
image_file_list = list(validate_image_dir.glob('*'))

# puma_url = "http://3.bp.blogspot.com/-eGxZHpshFcg/URxxonUCcfI/AAAAAAAAAN0/jvsnB1BHi9s/s1600/Logo+Puma+7.jpg"
# puma_path = tf.keras.utils.get_file('puma_img', origin=puma_url)
# img = tf.keras.preprocessing.image.load_img(puma_path, target_size=(img_height, img_width) )

for i in range(len(image_file_list)):
    print (image_file_list[i])
    img = tf.keras.preprocessing.image.load_img(image_file_list[i], target_size=(img_height, img_width) )
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0) # Create a batch

    predictions = model.predict(img_array)
    score = tf.nn.softmax(predictions[0])

    print("This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score)))
    print ("\n")
# Out:
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_0.jpg
# This image most likely belongs to Addidas with a 97.17 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_1.jpg
# This image most likely belongs to Addidas with a 84.28 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_10.jpg
# This image most likely belongs to Vans with a 63.10 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_12.jpg
# This image most likely belongs to Addidas with a 95.99 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_13.jpg
# This image most likely belongs to Addidas with a 99.97 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_14.jpg
# This image most likely belongs to Addidas with a 99.95 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_15.jpg
# This image most likely belongs to Husky with a 96.04 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_16.jpg
# This image most likely belongs to Addidas with a 60.09 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_17.jpg
# This image most likely belongs to Addidas with a 89.84 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_18.jpg
# This image most likely belongs to Addidas with a 99.99 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_19.jpg
# This image most likely belongs to Addidas with a 82.89 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_2.jpg
# This image most likely belongs to Addidas with a 79.14 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_20.jpg
# This image most likely belongs to Springfield with a 99.68 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_21.jpg
# This image most likely belongs to Unicef with a 26.45 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_22.jpg
# This image most likely belongs to Husky with a 92.45 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_23.jpg
# This image most likely belongs to Addidas with a 97.88 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_24.jpg
# This image most likely belongs to K-Swiss with a 52.82 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_26.jpg
# This image most likely belongs to Springfield with a 88.94 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_27.jpg
# This image most likely belongs to Springfield with a 93.05 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_28.jpg
# This image most likely belongs to Addidas with a 99.65 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_29.jpg
# This image most likely belongs to Addidas with a 99.89 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_3.jpg
# This image most likely belongs to Springfield with a 96.55 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_30.jpg
# This image most likely belongs to Unicef with a 63.36 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_31.jpg
# This image most likely belongs to Addidas with a 56.96 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_32.jpg
# This image most likely belongs to Springfield with a 98.59 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_33.jpg
# This image most likely belongs to Salewa with a 66.73 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_34.jpg
# This image most likely belongs to Springfield with a 73.27 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_4.jpg
# This image most likely belongs to Addidas with a 99.87 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_5.jpg
# This image most likely belongs to Addidas with a 99.62 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_6.jpg
# This image most likely belongs to Springfield with a 80.30 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_7.jpg
# This image most likely belongs to Addidas with a 94.96 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_8.jpg
# This image most likely belongs to Addidas with a 99.95 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\addidas_9.jpg
# This image most likely belongs to Addidas with a 99.25 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Birki's_0.jpg
# This image most likely belongs to Birki's with a 99.66 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Birki's_1.jpg
# This image most likely belongs to Birki's with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Birki's_10.jpg
# This image most likely belongs to Birki's with a 99.84 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Birki's_11.jpg
# This image most likely belongs to Birki's with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Birki's_12.jpg
# This image most likely belongs to Birki's with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Birki's_13.jpg
# This image most likely belongs to Birki's with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Birki's_14.jpg
# This image most likely belongs to Birki's with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Birki's_15.jpg
# This image most likely belongs to Birki's with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Birki's_16.jpg
# This image most likely belongs to Birki's with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Birki's_17.jpg
# This image most likely belongs to Birki's with a 99.99 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Birki's_18.jpg
# This image most likely belongs to Vans with a 44.93 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Birki's_19.jpg
# This image most likely belongs to Birki's with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Birki's_2.jpg
# This image most likely belongs to Springfield with a 69.34 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Birki's_20.jpg
# This image most likely belongs to Birki's with a 98.91 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Birki's_3.jpg
# This image most likely belongs to Birki's with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Birki's_4.jpg
# This image most likely belongs to Springfield with a 85.06 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Birki's_5.jpg
# This image most likely belongs to Birki's with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Birki's_6.jpg
# This image most likely belongs to Birki's with a 98.74 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Birki's_7.jpg
# This image most likely belongs to Birki's with a 99.91 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Birki's_8.jpg
# This image most likely belongs to Birki's with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Birki's_9.jpg
# This image most likely belongs to Birki's with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Brother_0.jpg
# This image most likely belongs to Brother with a 75.72 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Brother_1.jpg
# This image most likely belongs to Brother with a 64.21 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Brother_10.jpg
# This image most likely belongs to Unicef with a 54.98 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Brother_11.jpg
# This image most likely belongs to Husky with a 41.97 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Brother_12.jpg
# This image most likely belongs to Brother with a 36.18 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Brother_13.jpg
# This image most likely belongs to Brother with a 95.45 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Brother_14.jpg
# This image most likely belongs to Brother with a 78.72 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Brother_15.jpg
# This image most likely belongs to Brother with a 32.16 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Brother_16.jpg
# This image most likely belongs to Brother with a 72.70 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Brother_17.jpg
# This image most likely belongs to Brother with a 80.63 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Brother_18.jpg
# This image most likely belongs to Addidas with a 57.76 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Brother_19.jpg
# This image most likely belongs to Unicef with a 44.11 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Brother_2.jpg
# This image most likely belongs to Brother with a 95.37 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Brother_20.jpg
# This image most likely belongs to Brother with a 34.98 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Brother_3.jpg
# This image most likely belongs to Brother with a 49.10 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Brother_4.jpg
# This image most likely belongs to Unicef with a 38.83 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Brother_5.jpg
# This image most likely belongs to Brother with a 65.91 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Brother_6.jpg
# This image most likely belongs to Brother with a 96.13 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Brother_7.jpg
# This image most likely belongs to Husky with a 42.26 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Brother_8.jpg
# This image most likely belongs to Brother with a 83.09 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Brother_9.jpg
# This image most likely belongs to Unicef with a 43.14 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Hilleberg_0.jpg
# This image most likely belongs to Hilleberg with a 99.47 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Hilleberg_1.jpg
# This image most likely belongs to Hilleberg with a 97.37 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Hilleberg_10.jpg
# This image most likely belongs to Hilleberg with a 99.96 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Hilleberg_11.jpg
# This image most likely belongs to Hilleberg with a 88.07 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Hilleberg_12.jpg
# This image most likely belongs to Hilleberg with a 97.02 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Hilleberg_13.jpg
# This image most likely belongs to Springfield with a 29.99 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Hilleberg_14.jpg
# This image most likely belongs to Hilleberg with a 99.20 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Hilleberg_15.jpg
# This image most likely belongs to Hilleberg with a 99.50 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Hilleberg_16.jpg
# This image most likely belongs to Hilleberg with a 99.01 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Hilleberg_17.jpg
# This image most likely belongs to Hilleberg with a 99.48 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Hilleberg_18.jpg
# This image most likely belongs to Hilleberg with a 82.18 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Hilleberg_19.jpg
# This image most likely belongs to Hilleberg with a 99.29 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Hilleberg_2.jpg
# This image most likely belongs to Hilleberg with a 69.38 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Hilleberg_3.jpg
# This image most likely belongs to Hilleberg with a 34.56 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Hilleberg_4.jpg
# This image most likely belongs to Hilleberg with a 99.94 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Hilleberg_5.jpg
# This image most likely belongs to Springfield with a 96.86 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Hilleberg_6.jpg
# This image most likely belongs to Hilleberg with a 99.41 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Hilleberg_7.jpg
# This image most likely belongs to Hilleberg with a 99.28 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Hilleberg_8.jpg
# This image most likely belongs to Hilleberg with a 99.91 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Hilleberg_9.jpg
# This image most likely belongs to Hilleberg with a 94.07 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_0.jpg
# This image most likely belongs to Husky with a 95.39 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_1.jpg
# This image most likely belongs to Husky with a 99.15 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_10.jpg
# This image most likely belongs to Husky with a 82.53 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_11.jpg
# This image most likely belongs to Springfield with a 77.92 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_12.jpg
# This image most likely belongs to Springfield with a 80.36 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_13.jpg
# This image most likely belongs to Husky with a 80.14 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_14.jpg
# This image most likely belongs to Springfield with a 54.72 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_15.jpg
# This image most likely belongs to Addidas with a 53.61 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_16.jpg
# This image most likely belongs to Springfield with a 81.20 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_17.jpg
# This image most likely belongs to Springfield with a 69.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_18.jpg
# This image most likely belongs to Addidas with a 84.98 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_19.jpg
# This image most likely belongs to Husky with a 40.84 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_2.jpg
# This image most likely belongs to Husky with a 99.77 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_20.jpg
# This image most likely belongs to Husky with a 43.12 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_21.jpg
# This image most likely belongs to Springfield with a 99.57 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_22.jpg
# This image most likely belongs to Springfield with a 99.48 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_23.jpg
# This image most likely belongs to Vans with a 51.06 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_24.jpg
# This image most likely belongs to Springfield with a 66.27 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_25.jpg
# This image most likely belongs to Springfield with a 98.49 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_26.jpg
# This image most likely belongs to Vans with a 47.51 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_27.jpg
# This image most likely belongs to Husky with a 88.89 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_28.jpg
# This image most likely belongs to Addidas with a 70.69 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_29.jpg
# This image most likely belongs to Husky with a 89.28 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_3.jpg
# This image most likely belongs to Husky with a 95.77 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_30.jpg
# This image most likely belongs to Springfield with a 97.72 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_4.jpg
# This image most likely belongs to Husky with a 99.27 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_5.jpg
# This image most likely belongs to Vans with a 51.32 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_6.jpg
# This image most likely belongs to Husky with a 99.83 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_7.jpg
# This image most likely belongs to Springfield with a 94.39 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_8.jpg
# This image most likely belongs to Husky with a 99.79 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Husky_9.jpg
# This image most likely belongs to Springfield with a 64.92 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\K-Swiss_0.jpg
# This image most likely belongs to K-Swiss with a 82.28 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\K-Swiss_1.jpg
# This image most likely belongs to Springfield with a 70.93 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\K-Swiss_10.jpg
# This image most likely belongs to Springfield with a 70.37 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\K-Swiss_11.jpg
# This image most likely belongs to Vans with a 75.42 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\K-Swiss_12.jpg
# This image most likely belongs to K-Swiss with a 91.08 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\K-Swiss_2.jpg
# This image most likely belongs to K-Swiss with a 91.26 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\K-Swiss_3.jpg
# This image most likely belongs to K-Swiss with a 74.75 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\K-Swiss_4.jpg
# This image most likely belongs to Vans with a 89.01 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\K-Swiss_5.jpg
# This image most likely belongs to Springfield with a 60.29 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\K-Swiss_6.jpg
# This image most likely belongs to Springfield with a 95.88 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\K-Swiss_7.jpg
# This image most likely belongs to Springfield with a 95.29 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\K-Swiss_8.jpg
# This image most likely belongs to Springfield with a 97.05 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\K-Swiss_9.jpg
# This image most likely belongs to Springfield with a 64.47 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\pillsbury_0.jpg
# This image most likely belongs to Pillsbury with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\pillsbury_1.jpg
# This image most likely belongs to Pillsbury with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\pillsbury_10.jpg
# This image most likely belongs to Pillsbury with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\pillsbury_11.jpg
# This image most likely belongs to Pillsbury with a 99.94 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\pillsbury_12.jpg
# This image most likely belongs to Pillsbury with a 99.99 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\pillsbury_13.jpg
# This image most likely belongs to Pillsbury with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\pillsbury_14.jpg
# This image most likely belongs to Pillsbury with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\pillsbury_15.jpg
# This image most likely belongs to Husky with a 96.49 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\pillsbury_16.jpg
# This image most likely belongs to Pillsbury with a 99.91 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\pillsbury_17.jpg
# This image most likely belongs to Pillsbury with a 99.01 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\pillsbury_18.jpg
# This image most likely belongs to Pillsbury with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\pillsbury_19.jpg
# This image most likely belongs to Pillsbury with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\pillsbury_2.jpg
# This image most likely belongs to Pillsbury with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\pillsbury_20.jpg
# This image most likely belongs to Springfield with a 83.28 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\pillsbury_21.jpg
# This image most likely belongs to Husky with a 90.20 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\pillsbury_3.jpg
# This image most likely belongs to Pillsbury with a 99.99 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\pillsbury_4.jpg
# This image most likely belongs to Pillsbury with a 99.97 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\pillsbury_5.jpg
# This image most likely belongs to Pillsbury with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\pillsbury_6.jpg
# This image most likely belongs to Pillsbury with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\pillsbury_7.jpg
# This image most likely belongs to Pillsbury with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\pillsbury_8.jpg
# This image most likely belongs to Pillsbury with a 84.67 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\pillsbury_9.jpg
# This image most likely belongs to Husky with a 81.30 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_0.jpg
# This image most likely belongs to Salewa with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_1.jpg
# This image most likely belongs to Salewa with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_10.jpg
# This image most likely belongs to Salewa with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_11.jpg
# This image most likely belongs to Salewa with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_12.jpg
# This image most likely belongs to Salewa with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_13.jpg
# This image most likely belongs to Salewa with a 98.45 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_14.jpg
# This image most likely belongs to Salewa with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_15.jpg
# This image most likely belongs to Salewa with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_16.jpg
# This image most likely belongs to Husky with a 70.40 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_17.jpg
# This image most likely belongs to Salewa with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_18.jpg
# This image most likely belongs to Salewa with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_19.jpg
# This image most likely belongs to Salewa with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_2.jpg
# This image most likely belongs to Salewa with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_20.jpg
# This image most likely belongs to Salewa with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_21.jpg
# This image most likely belongs to Salewa with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_22.jpg
# This image most likely belongs to Salewa with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_23.jpg
# This image most likely belongs to Salewa with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_24.jpg
# This image most likely belongs to Salewa with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_25.jpg
# This image most likely belongs to Salewa with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_26.jpg
# This image most likely belongs to Salewa with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_27.jpg
# This image most likely belongs to Salewa with a 99.35 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_28.jpg
# This image most likely belongs to Salewa with a 99.41 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_29.jpg
# This image most likely belongs to Salewa with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_3.jpg
# This image most likely belongs to Salewa with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_4.jpg
# This image most likely belongs to Salewa with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_5.jpg
# This image most likely belongs to Salewa with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_6.jpg
# This image most likely belongs to Salewa with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_7.jpg
# This image most likely belongs to Salewa with a 99.98 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_8.jpg
# This image most likely belongs to Salewa with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Salewa_9.jpg
# This image most likely belongs to Salewa with a 61.96 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Springfield_0.jpg
# This image most likely belongs to Salewa with a 82.92 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Springfield_1.jpg
# This image most likely belongs to Husky with a 67.53 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Springfield_10.jpg
# This image most likely belongs to Springfield with a 59.70 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Springfield_11.jpg
# This image most likely belongs to Husky with a 97.44 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Springfield_12.jpg
# This image most likely belongs to Springfield with a 92.61 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Springfield_2.jpg
# This image most likely belongs to Springfield with a 90.16 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Springfield_3.jpg
# This image most likely belongs to Husky with a 51.31 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Springfield_4.jpg
# This image most likely belongs to Unicef with a 44.47 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Springfield_5.jpg
# This image most likely belongs to Vans with a 61.62 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Springfield_6.jpg
# This image most likely belongs to Springfield with a 59.93 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Springfield_7.jpg
# This image most likely belongs to Springfield with a 62.41 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Springfield_8.jpg
# This image most likely belongs to Springfield with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Springfield_9.jpg
# This image most likely belongs to Vans with a 74.38 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Unicef_0.jpg
# This image most likely belongs to Pillsbury with a 58.37 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Unicef_1.jpg
# This image most likely belongs to Unicef with a 99.16 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Unicef_10.jpg
# This image most likely belongs to White Castle with a 97.77 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Unicef_11.jpg
# This image most likely belongs to Unicef with a 95.61 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Unicef_12.jpg
# This image most likely belongs to Springfield with a 80.26 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Unicef_13.jpg
# This image most likely belongs to Springfield with a 91.51 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Unicef_14.jpg
# This image most likely belongs to Pillsbury with a 93.52 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Unicef_15.jpg
# This image most likely belongs to Springfield with a 99.74 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Unicef_16.jpg
# This image most likely belongs to Springfield with a 84.98 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Unicef_17.jpg
# This image most likely belongs to Springfield with a 72.06 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Unicef_18.jpg
# This image most likely belongs to Unicef with a 99.98 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Unicef_2.jpg
# This image most likely belongs to Springfield with a 99.92 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Unicef_3.jpg
# This image most likely belongs to Husky with a 75.75 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Unicef_4.jpg
# This image most likely belongs to Springfield with a 70.10 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Unicef_5.jpg
# This image most likely belongs to Springfield with a 69.11 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Unicef_6.jpg
# This image most likely belongs to Unicef with a 69.67 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Unicef_7.jpg
# This image most likely belongs to White Castle with a 97.83 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Unicef_8.jpg
# This image most likely belongs to Unicef with a 99.53 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Unicef_9.jpg
# This image most likely belongs to Unicef with a 46.78 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Vans_0.jpg
# This image most likely belongs to Vans with a 99.61 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Vans_1.jpg
# This image most likely belongs to Vans with a 98.12 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Vans_10.jpg
# This image most likely belongs to Vans with a 92.80 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Vans_11.jpg
# This image most likely belongs to Vans with a 99.97 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Vans_12.jpg
# This image most likely belongs to Vans with a 78.60 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Vans_13.jpg
# This image most likely belongs to Springfield with a 39.02 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Vans_14.jpg
# This image most likely belongs to Vans with a 52.78 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Vans_15.jpg
# This image most likely belongs to Vans with a 99.99 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Vans_16.jpg
# This image most likely belongs to Vans with a 97.95 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Vans_17.jpg
# This image most likely belongs to Springfield with a 99.17 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Vans_18.jpg
# This image most likely belongs to Springfield with a 98.92 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Vans_19.jpg
# This image most likely belongs to Vans with a 89.11 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Vans_2.jpg
# This image most likely belongs to Springfield with a 91.99 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Vans_20.jpg
# This image most likely belongs to Springfield with a 89.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Vans_3.jpg
# This image most likely belongs to Springfield with a 77.79 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Vans_4.jpg
# This image most likely belongs to Vans with a 99.88 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Vans_5.jpg
# This image most likely belongs to Vans with a 95.45 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Vans_6.jpg
# This image most likely belongs to Vans with a 99.49 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Vans_7.jpg
# This image most likely belongs to Vans with a 58.05 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Vans_8.jpg
# This image most likely belongs to Springfield with a 65.92 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\Vans_9.jpg
# This image most likely belongs to Springfield with a 94.31 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\White Castle_0.jpg
# This image most likely belongs to White Castle with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\White Castle_1.jpg
# This image most likely belongs to White Castle with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\White Castle_10.jpg
# This image most likely belongs to White Castle with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\White Castle_11.jpg
# This image most likely belongs to Vans with a 70.01 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\White Castle_12.jpg
# This image most likely belongs to White Castle with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\White Castle_13.jpg
# This image most likely belongs to Springfield with a 34.54 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\White Castle_14.jpg
# This image most likely belongs to White Castle with a 99.93 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\White Castle_15.jpg
# This image most likely belongs to White Castle with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\White Castle_16.jpg
# This image most likely belongs to White Castle with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\White Castle_17.jpg
# This image most likely belongs to White Castle with a 92.20 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\White Castle_18.jpg
# This image most likely belongs to White Castle with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\White Castle_19.jpg
# This image most likely belongs to White Castle with a 98.59 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\White Castle_2.jpg
# This image most likely belongs to White Castle with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\White Castle_20.jpg
# This image most likely belongs to White Castle with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\White Castle_21.jpg
# This image most likely belongs to White Castle with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\White Castle_22.jpg
# This image most likely belongs to White Castle with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\White Castle_23.jpg
# This image most likely belongs to White Castle with a 99.75 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\White Castle_24.jpg
# This image most likely belongs to White Castle with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\White Castle_25.jpg
# This image most likely belongs to Unicef with a 85.28 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\White Castle_26.jpg
# This image most likely belongs to White Castle with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\White Castle_3.jpg
# This image most likely belongs to White Castle with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\White Castle_4.jpg
# This image most likely belongs to White Castle with a 94.31 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\White Castle_5.jpg
# This image most likely belongs to White Castle with a 86.46 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\White Castle_6.jpg
# This image most likely belongs to White Castle with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\White Castle_7.jpg
# This image most likely belongs to White Castle with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\White Castle_8.jpg
# This image most likely belongs to White Castle with a 100.00 percent confidence.
#
#
# C:\Users\Admin\Desktop\ClothTestFolder\White Castle_9.jpg
# This image most likely belongs to White Castle with a 100.00 percent confidence.

# %%
model.save('model.h5')

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
# TEST THE MODEL
#from keras.preprocessing import image
# Test path for each image C:\Users\Admin\Desktop\ClothTestFolder

validate_image_dir = pathlib.Path("C:\\Users\\Admin\\Desktop\\ClothTestFolder\\")
image_file_list = list(validate_image_dir.glob('*'))

# puma_url = "http://3.bp.blogspot.com/-eGxZHpshFcg/URxxonUCcfI/AAAAAAAAAN0/jvsnB1BHi9s/s1600/Logo+Puma+7.jpg"
# puma_path = tf.keras.utils.get_file('puma_img', origin=puma_url)
# img = tf.keras.preprocessing.image.load_img(puma_path, target_size=(img_height, img_width) )
validated_True = 0
validated_False = 0 
for i in range(len(image_file_list)):
    #print (image_file_list[i])
    image_name = os.path.basename(image_file_list[i])   
    format_image_name = image_name.split("_")
    test_image_name = format_image_name[0]
    print (test_image_name)
    
    
    img = tf.keras.preprocessing.image.load_img(image_file_list[i], target_size=(img_height, img_width) )
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0) # Create a batch

    predictions = model.predict(img_array)
    score = tf.nn.softmax(predictions[0])

    print("This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score)))
    print (class_names[np.argmax(score)])
    
    if (test_image_name == class_names[np.argmax(score)].lower()):
        validated_True =+ 1
        print ("True")
     
    else:
        validated_False =+ 1
        print ("False")
    
        
    print ("\n")
    
print ("Total images correctly validated : ", validated_True) 
print ("Total images incorrectly validated : ", validated_False)
# Out:
# addidas
# This image most likely belongs to Addidas with a 97.17 percent confidence.
# Addidas
# True
#
#
# addidas
# This image most likely belongs to Addidas with a 84.28 percent confidence.
# Addidas
# True
#
#
# addidas
# This image most likely belongs to Vans with a 63.10 percent confidence.
# Vans
# False
#
#
# addidas
# This image most likely belongs to Addidas with a 95.99 percent confidence.
# Addidas
# True
#
#
# addidas
# This image most likely belongs to Addidas with a 99.97 percent confidence.
# Addidas
# True
#
#
# addidas
# This image most likely belongs to Addidas with a 99.95 percent confidence.
# Addidas
# True
#
#
# addidas
# This image most likely belongs to Husky with a 96.04 percent confidence.
# Husky
# False
#
#
# addidas
# This image most likely belongs to Addidas with a 60.09 percent confidence.
# Addidas
# True
#
#
# addidas
# This image most likely belongs to Addidas with a 89.84 percent confidence.
# Addidas
# True
#
#
# addidas
# This image most likely belongs to Addidas with a 99.99 percent confidence.
# Addidas
# True
#
#
# addidas
# This image most likely belongs to Addidas with a 82.89 percent confidence.
# Addidas
# True
#
#
# addidas
# This image most likely belongs to Addidas with a 79.14 percent confidence.
# Addidas
# True
#
#
# addidas
# This image most likely belongs to Springfield with a 99.68 percent confidence.
# Springfield
# False
#
#
# addidas
# This image most likely belongs to Unicef with a 26.45 percent confidence.
# Unicef
# False
#
#
# addidas
# This image most likely belongs to Husky with a 92.45 percent confidence.
# Husky
# False
#
#
# addidas
# This image most likely belongs to Addidas with a 97.88 percent confidence.
# Addidas
# True
#
#
# addidas
# This image most likely belongs to K-Swiss with a 52.82 percent confidence.
# K-Swiss
# False
#
#
# addidas
# This image most likely belongs to Springfield with a 88.94 percent confidence.
# Springfield
# False
#
#
# addidas
# This image most likely belongs to Springfield with a 93.05 percent confidence.
# Springfield
# False
#
#
# addidas
# This image most likely belongs to Addidas with a 99.65 percent confidence.
# Addidas
# True
#
#
# addidas
# This image most likely belongs to Addidas with a 99.89 percent confidence.
# Addidas
# True
#
#
# addidas
# This image most likely belongs to Springfield with a 96.55 percent confidence.
# Springfield
# False
#
#
# addidas
# This image most likely belongs to Unicef with a 63.36 percent confidence.
# Unicef
# False
#
#
# addidas
# This image most likely belongs to Addidas with a 56.96 percent confidence.
# Addidas
# True
#
#
# addidas
# This image most likely belongs to Springfield with a 98.59 percent confidence.
# Springfield
# False
#
#
# addidas
# This image most likely belongs to Salewa with a 66.73 percent confidence.
# Salewa
# False
#
#
# addidas
# This image most likely belongs to Springfield with a 73.27 percent confidence.
# Springfield
# False
#
#
# addidas
# This image most likely belongs to Addidas with a 99.87 percent confidence.
# Addidas
# True
#
#
# addidas
# This image most likely belongs to Addidas with a 99.62 percent confidence.
# Addidas
# True
#
#
# addidas
# This image most likely belongs to Springfield with a 80.30 percent confidence.
# Springfield
# False
#
#
# addidas
# This image most likely belongs to Addidas with a 94.96 percent confidence.
# Addidas
# True
#
#
# addidas
# This image most likely belongs to Addidas with a 99.95 percent confidence.
# Addidas
# True
#
#
# addidas
# This image most likely belongs to Addidas with a 99.25 percent confidence.
# Addidas
# True
#
#
# Birki's
# This image most likely belongs to Birki's with a 99.66 percent confidence.
# Birki's
# False
#
#
# Birki's
# This image most likely belongs to Birki's with a 100.00 percent confidence.
# Birki's
# False
#
#
# Birki's
# This image most likely belongs to Birki's with a 99.84 percent confidence.
# Birki's
# False
#
#
# Birki's
# This image most likely belongs to Birki's with a 100.00 percent confidence.
# Birki's
# False
#
#
# Birki's
# This image most likely belongs to Birki's with a 100.00 percent confidence.
# Birki's
# False
#
#
# Birki's
# This image most likely belongs to Birki's with a 100.00 percent confidence.
# Birki's
# False
#
#
# Birki's
# This image most likely belongs to Birki's with a 100.00 percent confidence.
# Birki's
# False
#
#
# Birki's
# This image most likely belongs to Birki's with a 100.00 percent confidence.
# Birki's
# False
#
#
# Birki's
# This image most likely belongs to Birki's with a 100.00 percent confidence.
# Birki's
# False
#
#
# Birki's
# This image most likely belongs to Birki's with a 99.99 percent confidence.
# Birki's
# False
#
#
# Birki's
# This image most likely belongs to Vans with a 44.93 percent confidence.
# Vans
# False
#
#
# Birki's
# This image most likely belongs to Birki's with a 100.00 percent confidence.
# Birki's
# False
#
#
# Birki's
# This image most likely belongs to Springfield with a 69.34 percent confidence.
# Springfield
# False
#
#
# Birki's
# This image most likely belongs to Birki's with a 98.91 percent confidence.
# Birki's
# False
#
#
# Birki's
# This image most likely belongs to Birki's with a 100.00 percent confidence.
# Birki's
# False
#
#
# Birki's
# This image most likely belongs to Springfield with a 85.06 percent confidence.
# Springfield
# False
#
#
# Birki's
# This image most likely belongs to Birki's with a 100.00 percent confidence.
# Birki's
# False
#
#
# Birki's
# This image most likely belongs to Birki's with a 98.74 percent confidence.
# Birki's
# False
#
#
# Birki's
# This image most likely belongs to Birki's with a 99.91 percent confidence.
# Birki's
# False
#
#
# Birki's
# This image most likely belongs to Birki's with a 100.00 percent confidence.
# Birki's
# False
#
#
# Birki's
# This image most likely belongs to Birki's with a 100.00 percent confidence.
# Birki's
# False
#
#
# Brother
# This image most likely belongs to Brother with a 75.72 percent confidence.
# Brother
# False
#
#
# Brother
# This image most likely belongs to Brother with a 64.21 percent confidence.
# Brother
# False
#
#
# Brother
# This image most likely belongs to Unicef with a 54.98 percent confidence.
# Unicef
# False
#
#
# Brother
# This image most likely belongs to Husky with a 41.97 percent confidence.
# Husky
# False
#
#
# Brother
# This image most likely belongs to Brother with a 36.18 percent confidence.
# Brother
# False
#
#
# Brother
# This image most likely belongs to Brother with a 95.45 percent confidence.
# Brother
# False
#
#
# Brother
# This image most likely belongs to Brother with a 78.72 percent confidence.
# Brother
# False
#
#
# Brother
# This image most likely belongs to Brother with a 32.16 percent confidence.
# Brother
# False
#
#
# Brother
# This image most likely belongs to Brother with a 72.70 percent confidence.
# Brother
# False
#
#
# Brother
# This image most likely belongs to Brother with a 80.63 percent confidence.
# Brother
# False
#
#
# Brother
# This image most likely belongs to Addidas with a 57.76 percent confidence.
# Addidas
# False
#
#
# Brother
# This image most likely belongs to Unicef with a 44.11 percent confidence.
# Unicef
# False
#
#
# Brother
# This image most likely belongs to Brother with a 95.37 percent confidence.
# Brother
# False
#
#
# Brother
# This image most likely belongs to Brother with a 34.98 percent confidence.
# Brother
# False
#
#
# Brother
# This image most likely belongs to Brother with a 49.10 percent confidence.
# Brother
# False
#
#
# Brother
# This image most likely belongs to Unicef with a 38.83 percent confidence.
# Unicef
# False
#
#
# Brother
# This image most likely belongs to Brother with a 65.91 percent confidence.
# Brother
# False
#
#
# Brother
# This image most likely belongs to Brother with a 96.13 percent confidence.
# Brother
# False
#
#
# Brother
# This image most likely belongs to Husky with a 42.26 percent confidence.
# Husky
# False
#
#
# Brother
# This image most likely belongs to Brother with a 83.09 percent confidence.
# Brother
# False
#
#
# Brother
# This image most likely belongs to Unicef with a 43.14 percent confidence.
# Unicef
# False
#
#
# Hilleberg
# This image most likely belongs to Hilleberg with a 99.47 percent confidence.
# Hilleberg
# False
#
#
# Hilleberg
# This image most likely belongs to Hilleberg with a 97.37 percent confidence.
# Hilleberg
# False
#
#
# Hilleberg
# This image most likely belongs to Hilleberg with a 99.96 percent confidence.
# Hilleberg
# False
#
#
# Hilleberg
# This image most likely belongs to Hilleberg with a 88.07 percent confidence.
# Hilleberg
# False
#
#
# Hilleberg
# This image most likely belongs to Hilleberg with a 97.02 percent confidence.
# Hilleberg
# False
#
#
# Hilleberg
# This image most likely belongs to Springfield with a 29.99 percent confidence.
# Springfield
# False
#
#
# Hilleberg
# This image most likely belongs to Hilleberg with a 99.20 percent confidence.
# Hilleberg
# False
#
#
# Hilleberg
# This image most likely belongs to Hilleberg with a 99.50 percent confidence.
# Hilleberg
# False
#
#
# Hilleberg
# This image most likely belongs to Hilleberg with a 99.01 percent confidence.
# Hilleberg
# False
#
#
# Hilleberg
# This image most likely belongs to Hilleberg with a 99.48 percent confidence.
# Hilleberg
# False
#
#
# Hilleberg
# This image most likely belongs to Hilleberg with a 82.18 percent confidence.
# Hilleberg
# False
#
#
# Hilleberg
# This image most likely belongs to Hilleberg with a 99.29 percent confidence.
# Hilleberg
# False
#
#
# Hilleberg
# This image most likely belongs to Hilleberg with a 69.38 percent confidence.
# Hilleberg
# False
#
#
# Hilleberg
# This image most likely belongs to Hilleberg with a 34.56 percent confidence.
# Hilleberg
# False
#
#
# Hilleberg
# This image most likely belongs to Hilleberg with a 99.94 percent confidence.
# Hilleberg
# False
#
#
# Hilleberg
# This image most likely belongs to Springfield with a 96.86 percent confidence.
# Springfield
# False
#
#
# Hilleberg
# This image most likely belongs to Hilleberg with a 99.41 percent confidence.
# Hilleberg
# False
#
#
# Hilleberg
# This image most likely belongs to Hilleberg with a 99.28 percent confidence.
# Hilleberg
# False
#
#
# Hilleberg
# This image most likely belongs to Hilleberg with a 99.91 percent confidence.
# Hilleberg
# False
#
#
# Hilleberg
# This image most likely belongs to Hilleberg with a 94.07 percent confidence.
# Hilleberg
# False
#
#
# Husky
# This image most likely belongs to Husky with a 95.39 percent confidence.
# Husky
# False
#
#
# Husky
# This image most likely belongs to Husky with a 99.15 percent confidence.
# Husky
# False
#
#
# Husky
# This image most likely belongs to Husky with a 82.53 percent confidence.
# Husky
# False
#
#
# Husky
# This image most likely belongs to Springfield with a 77.92 percent confidence.
# Springfield
# False
#
#
# Husky
# This image most likely belongs to Springfield with a 80.36 percent confidence.
# Springfield
# False
#
#
# Husky
# This image most likely belongs to Husky with a 80.14 percent confidence.
# Husky
# False
#
#
# Husky
# This image most likely belongs to Springfield with a 54.72 percent confidence.
# Springfield
# False
#
#
# Husky
# This image most likely belongs to Addidas with a 53.61 percent confidence.
# Addidas
# False
#
#
# Husky
# This image most likely belongs to Springfield with a 81.20 percent confidence.
# Springfield
# False
#
#
# Husky
# This image most likely belongs to Springfield with a 69.00 percent confidence.
# Springfield
# False
#
#
# Husky
# This image most likely belongs to Addidas with a 84.98 percent confidence.
# Addidas
# False
#
#
# Husky
# This image most likely belongs to Husky with a 40.84 percent confidence.
# Husky
# False
#
#
# Husky
# This image most likely belongs to Husky with a 99.77 percent confidence.
# Husky
# False
#
#
# Husky
# This image most likely belongs to Husky with a 43.12 percent confidence.
# Husky
# False
#
#
# Husky
# This image most likely belongs to Springfield with a 99.57 percent confidence.
# Springfield
# False
#
#
# Husky
# This image most likely belongs to Springfield with a 99.48 percent confidence.
# Springfield
# False
#
#
# Husky
# This image most likely belongs to Vans with a 51.06 percent confidence.
# Vans
# False
#
#
# Husky
# This image most likely belongs to Springfield with a 66.27 percent confidence.
# Springfield
# False
#
#
# Husky
# This image most likely belongs to Springfield with a 98.49 percent confidence.
# Springfield
# False
#
#
# Husky
# This image most likely belongs to Vans with a 47.51 percent confidence.
# Vans
# False
#
#
# Husky
# This image most likely belongs to Husky with a 88.89 percent confidence.
# Husky
# False
#
#
# Husky
# This image most likely belongs to Addidas with a 70.69 percent confidence.
# Addidas
# False
#
#
# Husky
# This image most likely belongs to Husky with a 89.28 percent confidence.
# Husky
# False
#
#
# Husky
# This image most likely belongs to Husky with a 95.77 percent confidence.
# Husky
# False
#
#
# Husky
# This image most likely belongs to Springfield with a 97.72 percent confidence.
# Springfield
# False
#
#
# Husky
# This image most likely belongs to Husky with a 99.27 percent confidence.
# Husky
# False
#
#
# Husky
# This image most likely belongs to Vans with a 51.32 percent confidence.
# Vans
# False
#
#
# Husky
# This image most likely belongs to Husky with a 99.83 percent confidence.
# Husky
# False
#
#
# Husky
# This image most likely belongs to Springfield with a 94.39 percent confidence.
# Springfield
# False
#
#
# Husky
# This image most likely belongs to Husky with a 99.79 percent confidence.
# Husky
# False
#
#
# Husky
# This image most likely belongs to Springfield with a 64.92 percent confidence.
# Springfield
# False
#
#
# K-Swiss
# This image most likely belongs to K-Swiss with a 82.28 percent confidence.
# K-Swiss
# False
#
#
# K-Swiss
# This image most likely belongs to Springfield with a 70.93 percent confidence.
# Springfield
# False
#
#
# K-Swiss
# This image most likely belongs to Springfield with a 70.37 percent confidence.
# Springfield
# False
#
#
# K-Swiss
# This image most likely belongs to Vans with a 75.42 percent confidence.
# Vans
# False
#
#
# K-Swiss
# This image most likely belongs to K-Swiss with a 91.08 percent confidence.
# K-Swiss
# False
#
#
# K-Swiss
# This image most likely belongs to K-Swiss with a 91.26 percent confidence.
# K-Swiss
# False
#
#
# K-Swiss
# This image most likely belongs to K-Swiss with a 74.75 percent confidence.
# K-Swiss
# False
#
#
# K-Swiss
# This image most likely belongs to Vans with a 89.01 percent confidence.
# Vans
# False
#
#
# K-Swiss
# This image most likely belongs to Springfield with a 60.29 percent confidence.
# Springfield
# False
#
#
# K-Swiss
# This image most likely belongs to Springfield with a 95.88 percent confidence.
# Springfield
# False
#
#
# K-Swiss
# This image most likely belongs to Springfield with a 95.29 percent confidence.
# Springfield
# False
#
#
# K-Swiss
# This image most likely belongs to Springfield with a 97.05 percent confidence.
# Springfield
# False
#
#
# K-Swiss
# This image most likely belongs to Springfield with a 64.47 percent confidence.
# Springfield
# False
#
#
# pillsbury
# This image most likely belongs to Pillsbury with a 100.00 percent confidence.
# Pillsbury
# True
#
#
# pillsbury
# This image most likely belongs to Pillsbury with a 100.00 percent confidence.
# Pillsbury
# True
#
#
# pillsbury
# This image most likely belongs to Pillsbury with a 100.00 percent confidence.
# Pillsbury
# True
#
#
# pillsbury
# This image most likely belongs to Pillsbury with a 99.94 percent confidence.
# Pillsbury
# True
#
#
# pillsbury
# This image most likely belongs to Pillsbury with a 99.99 percent confidence.
# Pillsbury
# True
#
#
# pillsbury
# This image most likely belongs to Pillsbury with a 100.00 percent confidence.
# Pillsbury
# True
#
#
# pillsbury
# This image most likely belongs to Pillsbury with a 100.00 percent confidence.
# Pillsbury
# True
#
#
# pillsbury
# This image most likely belongs to Husky with a 96.49 percent confidence.
# Husky
# False
#
#
# pillsbury
# This image most likely belongs to Pillsbury with a 99.91 percent confidence.
# Pillsbury
# True
#
#
# pillsbury
# This image most likely belongs to Pillsbury with a 99.01 percent confidence.
# Pillsbury
# True
#
#
# pillsbury
# This image most likely belongs to Pillsbury with a 100.00 percent confidence.
# Pillsbury
# True
#
#
# pillsbury
# This image most likely belongs to Pillsbury with a 100.00 percent confidence.
# Pillsbury
# True
#
#
# pillsbury
# This image most likely belongs to Pillsbury with a 100.00 percent confidence.
# Pillsbury
# True
#
#
# pillsbury
# This image most likely belongs to Springfield with a 83.28 percent confidence.
# Springfield
# False
#
#
# pillsbury
# This image most likely belongs to Husky with a 90.20 percent confidence.
# Husky
# False
#
#
# pillsbury
# This image most likely belongs to Pillsbury with a 99.99 percent confidence.
# Pillsbury
# True
#
#
# pillsbury
# This image most likely belongs to Pillsbury with a 99.97 percent confidence.
# Pillsbury
# True
#
#
# pillsbury
# This image most likely belongs to Pillsbury with a 100.00 percent confidence.
# Pillsbury
# True
#
#
# pillsbury
# This image most likely belongs to Pillsbury with a 100.00 percent confidence.
# Pillsbury
# True
#
#
# pillsbury
# This image most likely belongs to Pillsbury with a 100.00 percent confidence.
# Pillsbury
# True
#
#
# pillsbury
# This image most likely belongs to Pillsbury with a 84.67 percent confidence.
# Pillsbury
# True
#
#
# pillsbury
# This image most likely belongs to Husky with a 81.30 percent confidence.
# Husky
# False
#
#
# Salewa
# This image most likely belongs to Salewa with a 100.00 percent confidence.
# Salewa
# False
#
#
# Salewa
# This image most likely belongs to Salewa with a 100.00 percent confidence.
# Salewa
# False
#
#
# Salewa
# This image most likely belongs to Salewa with a 100.00 percent confidence.
# Salewa
# False
#
#
# Salewa
# This image most likely belongs to Salewa with a 100.00 percent confidence.
# Salewa
# False
#
#
# Salewa
# This image most likely belongs to Salewa with a 100.00 percent confidence.
# Salewa
# False
#
#
# Salewa
# This image most likely belongs to Salewa with a 98.45 percent confidence.
# Salewa
# False
#
#
# Salewa
# This image most likely belongs to Salewa with a 100.00 percent confidence.
# Salewa
# False
#
#
# Salewa
# This image most likely belongs to Salewa with a 100.00 percent confidence.
# Salewa
# False
#
#
# Salewa
# This image most likely belongs to Husky with a 70.40 percent confidence.
# Husky
# False
#
#
# Salewa
# This image most likely belongs to Salewa with a 100.00 percent confidence.
# Salewa
# False
#
#
# Salewa
# This image most likely belongs to Salewa with a 100.00 percent confidence.
# Salewa
# False
#
#
# Salewa
# This image most likely belongs to Salewa with a 100.00 percent confidence.
# Salewa
# False
#
#
# Salewa
# This image most likely belongs to Salewa with a 100.00 percent confidence.
# Salewa
# False
#
#
# Salewa
# This image most likely belongs to Salewa with a 100.00 percent confidence.
# Salewa
# False
#
#
# Salewa
# This image most likely belongs to Salewa with a 100.00 percent confidence.
# Salewa
# False
#
#
# Salewa
# This image most likely belongs to Salewa with a 100.00 percent confidence.
# Salewa
# False
#
#
# Salewa
# This image most likely belongs to Salewa with a 100.00 percent confidence.
# Salewa
# False
#
#
# Salewa
# This image most likely belongs to Salewa with a 100.00 percent confidence.
# Salewa
# False
#
#
# Salewa
# This image most likely belongs to Salewa with a 100.00 percent confidence.
# Salewa
# False
#
#
# Salewa
# This image most likely belongs to Salewa with a 100.00 percent confidence.
# Salewa
# False
#
#
# Salewa
# This image most likely belongs to Salewa with a 99.35 percent confidence.
# Salewa
# False
#
#
# Salewa
# This image most likely belongs to Salewa with a 99.41 percent confidence.
# Salewa
# False
#
#
# Salewa
# This image most likely belongs to Salewa with a 100.00 percent confidence.
# Salewa
# False
#
#
# Salewa
# This image most likely belongs to Salewa with a 100.00 percent confidence.
# Salewa
# False
#
#
# Salewa
# This image most likely belongs to Salewa with a 100.00 percent confidence.
# Salewa
# False
#
#
# Salewa
# This image most likely belongs to Salewa with a 100.00 percent confidence.
# Salewa
# False
#
#
# Salewa
# This image most likely belongs to Salewa with a 100.00 percent confidence.
# Salewa
# False
#
#
# Salewa
# This image most likely belongs to Salewa with a 99.98 percent confidence.
# Salewa
# False
#
#
# Salewa
# This image most likely belongs to Salewa with a 100.00 percent confidence.
# Salewa
# False
#
#
# Salewa
# This image most likely belongs to Salewa with a 61.96 percent confidence.
# Salewa
# False
#
#
# Springfield
# This image most likely belongs to Salewa with a 82.92 percent confidence.
# Salewa
# False
#
#
# Springfield
# This image most likely belongs to Husky with a 67.53 percent confidence.
# Husky
# False
#
#
# Springfield
# This image most likely belongs to Springfield with a 59.70 percent confidence.
# Springfield
# False
#
#
# Springfield
# This image most likely belongs to Husky with a 97.44 percent confidence.
# Husky
# False
#
#
# Springfield
# This image most likely belongs to Springfield with a 92.61 percent confidence.
# Springfield
# False
#
#
# Springfield
# This image most likely belongs to Springfield with a 90.16 percent confidence.
# Springfield
# False
#
#
# Springfield
# This image most likely belongs to Husky with a 51.31 percent confidence.
# Husky
# False
#
#
# Springfield
# This image most likely belongs to Unicef with a 44.47 percent confidence.
# Unicef
# False
#
#
# Springfield
# This image most likely belongs to Vans with a 61.62 percent confidence.
# Vans
# False
#
#
# Springfield
# This image most likely belongs to Springfield with a 59.93 percent confidence.
# Springfield
# False
#
#
# Springfield
# This image most likely belongs to Springfield with a 62.41 percent confidence.
# Springfield
# False
#
#
# Springfield
# This image most likely belongs to Springfield with a 100.00 percent confidence.
# Springfield
# False
#
#
# Springfield
# This image most likely belongs to Vans with a 74.38 percent confidence.
# Vans
# False
#
#
# Unicef
# This image most likely belongs to Pillsbury with a 58.37 percent confidence.
# Pillsbury
# False
#
#
# Unicef
# This image most likely belongs to Unicef with a 99.16 percent confidence.
# Unicef
# False
#
#
# Unicef
# This image most likely belongs to White Castle with a 97.77 percent confidence.
# White Castle
# False
#
#
# Unicef
# This image most likely belongs to Unicef with a 95.61 percent confidence.
# Unicef
# False
#
#
# Unicef
# This image most likely belongs to Springfield with a 80.26 percent confidence.
# Springfield
# False
#
#
# Unicef
# This image most likely belongs to Springfield with a 91.51 percent confidence.
# Springfield
# False
#
#
# Unicef
# This image most likely belongs to Pillsbury with a 93.52 percent confidence.
# Pillsbury
# False
#
#
# Unicef
# This image most likely belongs to Springfield with a 99.74 percent confidence.
# Springfield
# False
#
#
# Unicef
# This image most likely belongs to Springfield with a 84.98 percent confidence.
# Springfield
# False
#
#
# Unicef
# This image most likely belongs to Springfield with a 72.06 percent confidence.
# Springfield
# False
#
#
# Unicef
# This image most likely belongs to Unicef with a 99.98 percent confidence.
# Unicef
# False
#
#
# Unicef
# This image most likely belongs to Springfield with a 99.92 percent confidence.
# Springfield
# False
#
#
# Unicef
# This image most likely belongs to Husky with a 75.75 percent confidence.
# Husky
# False
#
#
# Unicef
# This image most likely belongs to Springfield with a 70.10 percent confidence.
# Springfield
# False
#
#
# Unicef
# This image most likely belongs to Springfield with a 69.11 percent confidence.
# Springfield
# False
#
#
# Unicef
# This image most likely belongs to Unicef with a 69.67 percent confidence.
# Unicef
# False
#
#
# Unicef
# This image most likely belongs to White Castle with a 97.83 percent confidence.
# White Castle
# False
#
#
# Unicef
# This image most likely belongs to Unicef with a 99.53 percent confidence.
# Unicef
# False
#
#
# Unicef
# This image most likely belongs to Unicef with a 46.78 percent confidence.
# Unicef
# False
#
#
# Vans
# This image most likely belongs to Vans with a 99.61 percent confidence.
# Vans
# False
#
#
# Vans
# This image most likely belongs to Vans with a 98.12 percent confidence.
# Vans
# False
#
#
# Vans
# This image most likely belongs to Vans with a 92.80 percent confidence.
# Vans
# False
#
#
# Vans
# This image most likely belongs to Vans with a 99.97 percent confidence.
# Vans
# False
#
#
# Vans
# This image most likely belongs to Vans with a 78.60 percent confidence.
# Vans
# False
#
#
# Vans
# This image most likely belongs to Springfield with a 39.02 percent confidence.
# Springfield
# False
#
#
# Vans
# This image most likely belongs to Vans with a 52.78 percent confidence.
# Vans
# False
#
#
# Vans
# This image most likely belongs to Vans with a 99.99 percent confidence.
# Vans
# False
#
#
# Vans
# This image most likely belongs to Vans with a 97.95 percent confidence.
# Vans
# False
#
#
# Vans
# This image most likely belongs to Springfield with a 99.17 percent confidence.
# Springfield
# False
#
#
# Vans
# This image most likely belongs to Springfield with a 98.92 percent confidence.
# Springfield
# False
#
#
# Vans
# This image most likely belongs to Vans with a 89.11 percent confidence.
# Vans
# False
#
#
# Vans
# This image most likely belongs to Springfield with a 91.99 percent confidence.
# Springfield
# False
#
#
# Vans
# This image most likely belongs to Springfield with a 89.00 percent confidence.
# Springfield
# False
#
#
# Vans
# This image most likely belongs to Springfield with a 77.79 percent confidence.
# Springfield
# False
#
#
# Vans
# This image most likely belongs to Vans with a 99.88 percent confidence.
# Vans
# False
#
#
# Vans
# This image most likely belongs to Vans with a 95.45 percent confidence.
# Vans
# False
#
#
# Vans
# This image most likely belongs to Vans with a 99.49 percent confidence.
# Vans
# False
#
#
# Vans
# This image most likely belongs to Vans with a 58.05 percent confidence.
# Vans
# False
#
#
# Vans
# This image most likely belongs to Springfield with a 65.92 percent confidence.
# Springfield
# False
#
#
# Vans
# This image most likely belongs to Springfield with a 94.31 percent confidence.
# Springfield
# False
#
#
# White Castle
# This image most likely belongs to White Castle with a 100.00 percent confidence.
# White Castle
# False
#
#
# White Castle
# This image most likely belongs to White Castle with a 100.00 percent confidence.
# White Castle
# False
#
#
# White Castle
# This image most likely belongs to White Castle with a 100.00 percent confidence.
# White Castle
# False
#
#
# White Castle
# This image most likely belongs to Vans with a 70.01 percent confidence.
# Vans
# False
#
#
# White Castle
# This image most likely belongs to White Castle with a 100.00 percent confidence.
# White Castle
# False
#
#
# White Castle
# This image most likely belongs to Springfield with a 34.54 percent confidence.
# Springfield
# False
#
#
# White Castle
# This image most likely belongs to White Castle with a 99.93 percent confidence.
# White Castle
# False
#
#
# White Castle
# This image most likely belongs to White Castle with a 100.00 percent confidence.
# White Castle
# False
#
#
# White Castle
# This image most likely belongs to White Castle with a 100.00 percent confidence.
# White Castle
# False
#
#
# White Castle
# This image most likely belongs to White Castle with a 92.20 percent confidence.
# White Castle
# False
#
#
# White Castle
# This image most likely belongs to White Castle with a 100.00 percent confidence.
# White Castle
# False
#
#
# White Castle
# This image most likely belongs to White Castle with a 98.59 percent confidence.
# White Castle
# False
#
#
# White Castle
# This image most likely belongs to White Castle with a 100.00 percent confidence.
# White Castle
# False
#
#
# White Castle
# This image most likely belongs to White Castle with a 100.00 percent confidence.
# White Castle
# False
#
#
# White Castle
# This image most likely belongs to White Castle with a 100.00 percent confidence.
# White Castle
# False
#
#
# White Castle
# This image most likely belongs to White Castle with a 100.00 percent confidence.
# White Castle
# False
#
#
# White Castle
# This image most likely belongs to White Castle with a 99.75 percent confidence.
# White Castle
# False
#
#
# White Castle
# This image most likely belongs to White Castle with a 100.00 percent confidence.
# White Castle
# False
#
#
# White Castle
# This image most likely belongs to Unicef with a 85.28 percent confidence.
# Unicef
# False
#
#
# White Castle
# This image most likely belongs to White Castle with a 100.00 percent confidence.
# White Castle
# False
#
#
# White Castle
# This image most likely belongs to White Castle with a 100.00 percent confidence.
# White Castle
# False
#
#
# White Castle
# This image most likely belongs to White Castle with a 94.31 percent confidence.
# White Castle
# False
#
#
# White Castle
# This image most likely belongs to White Castle with a 86.46 percent confidence.
# White Castle
# False
#
#
# White Castle
# This image most likely belongs to White Castle with a 100.00 percent confidence.
# White Castle
# False
#
#
# White Castle
# This image most likely belongs to White Castle with a 100.00 percent confidence.
# White Castle
# False
#
#
# White Castle
# This image most likely belongs to White Castle with a 100.00 percent confidence.
# White Castle
# False
#
#
# White Castle
# This image most likely belongs to White Castle with a 100.00 percent confidence.
# White Castle
# False
#
#
# Total images correctly validated :  1
# Total images incorrectly validated :  1
